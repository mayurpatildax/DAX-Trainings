# %% [markdown]
# <a href="https://colab.research.google.com/github/mayurpatildax/DAX-Trainings/blob/master/Data%20Engineering%5CDonor_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.3.0)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.5)

# %% [markdown]
# ### Data Engineering Assignment
#
# #### Assignment - Donations to political parties summary
#
# ##### Problem Statement - Create the columns based on given requirements

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# 1. Importing the Donation dataset

# %%
df = spark.read.option("multiline", True).json("/content/drive/MyDrive/Colab Notebooks/donation_np.json")

# %%
df.printSchema()
# Out:
# root
#  |-- Address: string (nullable = true)
#  |-- Amount: string (nullable = true)
#  |-- Contribution Mode: string (nullable = true)
#  |-- Financial Year: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- PAN Given: string (nullable = true)
#  |-- Party: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- field10: string (nullable = true)
#  |-- field11: string (nullable = true)
#  |-- field12: string (nullable = true)
#  |-- field13: string (nullable = true)
#  |-- field14: string (nullable = true)
#  |-- field9: string (nullable = true)

# %%
df.show()
# Out:
# +--------------------+--------+--------------------+--------------+--------------------+---------+------+------+-------+-------+-------+-------+-------+------+
# |             Address|  Amount|   Contribution Mode|Financial Year|                Name|PAN Given| Party|  Type|field10|field11|field12|field13|field14|field9|
# +--------------------+--------+--------------------+--------------+--------------------+---------+------+------+-------+-------+-------+-------+-------+------+
# |16-B, Ferozeshah ...| 3000000|                CASH|       2010-11|          Aziz Pasha|        Y|   CPI|Others|       |       |       |       |       |      |
# |No.1, First Floor...|10000000|000037, HDFC Bank...|       2014-15|    V K Ramachandran|        Y|CPI(M)|Others|       |       |       |       |       |      |
# |3, Motilal Nehru ...|  108000|Cheque, State Ban...|       2014-15|  Dr. Manmohan Singh|        N|   INC|Others|       |       |       |       |       |      |
# |9,Firozshah Road ...|   54000|Through Bank Tran...|       2011-12| Dr. Manda Jagnathan|        N|   INC|Others|       |       |       |       |       |      |
# |17,Dr.B.R.Mehta L...|   54000|Through Bank Tran...|       2011-12|    Prof. K.V.Thomas|        N|   INC|Others|       |       |       |       |       |      |
# |31 Shamla Hills B...|  100000|          146865 SBI|       2011-12|     Sweta Chyouksey|        Y|   BJP|Others|       |       |       |       |       |      |
# |45 Bunglows Bhopa...|  100000|          994966 SBI|       2011-12|   Uma Shankar Gupta|        N|   BJP|Others|       |       |       |       |       |      |
# |                  --|   25000|14021,  Union Ban...|       2013-14|Parshwanath Bhakt...|        N|   BJP|Others|       |       |       |       |       |      |
# |9 Santoshi Ayodhy...|  100000|          168278 SBI|       2011-12|Anand Constructio...|        Y|   BJP|Others|       |       |       |       |       |      |
# |197, North Avenue...|   54000|       Bank Transfer|       2013-14|       Kamal Kashore|        N|   INC|Others|       |       |       |       |       |      |
# |              Mumbai|  100000|955592 Bank Of In...|       2004-05|          R.V Pandit|        N|   BJP|Others|       |       |       |       |       |      |
# |                  --|  100000|              430969|       2012-13|      A & T Infracon|        N|   BJP|Others|       |       |       |       |       |      |
# |G/3 Phonix Buildi...|  300000|Cheque No.884045 ...|       2008-09|A 2 Z online  Ser...|        N|   BJP|Others|       |       |       |       |       |      |
# |G/3 Phonix Buildi...|  200000|Cheque No-  88404...|       2008-09|A 2 Z online  Ser...|        N|   BJP|Others|       |       |       |       |       |      |
# |G/3 Phonix Buildi...|  200000|Cheque No-  88404...|       2008-09|A 2 Z online  Ser...|        N|   BJP|Others|       |       |       |       |       |      |
# |                  --|  125000|952450, Saraswat ...|       2012-13|A B Rolling Mills...|        N|   BJP|Others|       |       |       |       |       |      |
# |82, Narbada Road ...|  100000|72437 Allahabad Bank|       2011-12|           A C Dixit|        N|   BJP|Others|       |       |       |       |       |      |
# |S.F.S. Tirupati A...|  100000|174993, Union Ban...|       2014-15|        A D Builders|        Y|   BJP|Others|       |       |       |       |       |      |
# |                  --|   21000|            234, BOI|       2012-13|               A Fox|        N|   BJP|Others|       |       |       |       |       |      |
# |211/213, Raja Bha...|  100000|Ch. No. 62063/dtd...|       2009-10|A Mahendra Jewellers|        Y|   INC|Others|       |       |       |       |       |      |
# +--------------------+--------+--------------------+--------------+--------------------+---------+------+------+-------+-------+-------+-------+-------+------+
# only showing top 20 rows

# %% [markdown]
# 2. Update the column names
#
#     a. Contribution Mode to mode_of_payment \n
#
#     b. Financial Year to fin_year
#
#     c. Pan Given to pan_given

# %%
df2 = df.withColumnRenamed("Contribution Mode","mode_of_payment").withColumnRenamed("Financial Year","fin_year").withColumnRenamed("PAN Given", "pan_given")
df2.printSchema()
df2.show()
# Out:
# root
#  |-- Address: string (nullable = true)
#  |-- Amount: string (nullable = true)
#  |-- mode_of_payment: string (nullable = true)
#  |-- fin_year: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- pan_given: string (nullable = true)
#  |-- Party: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- field10: string (nullable = true)
#  |-- field11: string (nullable = true)
#  |-- field12: string (nullable = true)
#  |-- field13: string (nullable = true)
#  |-- field14: string (nullable = true)
#  |-- field9: string (nullable = true)
#
# +--------------------+--------+--------------------+--------+--------------------+---------+------+------+-------+-------+-------+-------+-------+------+
# |             Address|  Amount|     mode_of_payment|fin_year|                Name|pan_given| Party|  Type|field10|field11|field12|field13|field14|field9|
# +--------------------+--------+--------------------+--------+--------------------+---------+------+------+-------+-------+-------+-------+-------+------+
# |16-B, Ferozeshah ...| 3000000|                CASH| 2010-11|          Aziz Pasha|        Y|   CPI|Others|       |       |       |       |       |      |
# |No.1, First Floor...|10000000|000037, HDFC Bank...| 2014-15|    V K Ramachandran|        Y|CPI(M)|Others|       |       |       |       |       |      |
# |3, Motilal Nehru ...|  108000|Cheque, State Ban...| 2014-15|  Dr. Manmohan Singh|        N|   INC|Others|       |       |       |       |       |      |
# |9,Firozshah Road ...|   54000|Through Bank Tran...| 2011-12| Dr. Manda Jagnathan|        N|   INC|Others|       |       |       |       |       |      |
# |17,Dr.B.R.Mehta L...|   54000|Through Bank Tran...| 2011-12|    Prof. K.V.Thomas|        N|   INC|Others|       |       |       |       |       |      |
# |31 Shamla Hills B...|  100000|          146865 SBI| 2011-12|     Sweta Chyouksey|        Y|   BJP|Others|       |       |       |       |       |      |
# |45 Bunglows Bhopa...|  100000|          994966 SBI| 2011-12|   Uma Shankar Gupta|        N|   BJP|Others|       |       |       |       |       |      |
# |                  --|   25000|14021,  Union Ban...| 2013-14|Parshwanath Bhakt...|        N|   BJP|Others|       |       |       |       |       |      |
# |9 Santoshi Ayodhy...|  100000|          168278 SBI| 2011-12|Anand Constructio...|        Y|   BJP|Others|       |       |       |       |       |      |
# |197, North Avenue...|   54000|       Bank Transfer| 2013-14|       Kamal Kashore|        N|   INC|Others|       |       |       |       |       |      |
# |              Mumbai|  100000|955592 Bank Of In...| 2004-05|          R.V Pandit|        N|   BJP|Others|       |       |       |       |       |      |
# |                  --|  100000|              430969| 2012-13|      A & T Infracon|        N|   BJP|Others|       |       |       |       |       |      |
# |G/3 Phonix Buildi...|  300000|Cheque No.884045 ...| 2008-09|A 2 Z online  Ser...|        N|   BJP|Others|       |       |       |       |       |      |
# |G/3 Phonix Buildi...|  200000|Cheque No-  88404...| 2008-09|A 2 Z online  Ser...|        N|   BJP|Others|       |       |       |       |       |      |
# |G/3 Phonix Buildi...|  200000|Cheque No-  88404...| 2008-09|A 2 Z online  Ser...|        N|   BJP|Others|       |       |       |       |       |      |
# |                  --|  125000|952450, Saraswat ...| 2012-13|A B Rolling Mills...|        N|   BJP|Others|       |       |       |       |       |      |
# |82, Narbada Road ...|  100000|72437 Allahabad Bank| 2011-12|           A C Dixit|        N|   BJP|Others|       |       |       |       |       |      |
# |S.F.S. Tirupati A...|  100000|174993, Union Ban...| 2014-15|        A D Builders|        Y|   BJP|Others|       |       |       |       |       |      |
# |                  --|   21000|            234, BOI| 2012-13|               A Fox|        N|   BJP|Others|       |       |       |       |       |      |
# |211/213, Raja Bha...|  100000|Ch. No. 62063/dtd...| 2009-10|A Mahendra Jewellers|        Y|   INC|Others|       |       |       |       |       |      |
# +--------------------+--------+--------------------+--------+--------------------+---------+------+------+-------+-------+-------+-------+-------+------+
# only showing top 20 rows

# %% [markdown]
# 3. Encrypt the address column

# %%
# Hashing Function
import hashlib
def encrypt_value(address):
    sha_value = hashlib.sha256(address.encode()).hexdigest()
    return sha_value

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import *

spark_udf = udf(encrypt_value, StringType())
df2 = df2.withColumn('Address',spark_udf('Address'))

# %%
df2.printSchema()
# Out:
# root
#  |-- Address: string (nullable = true)
#  |-- Amount: string (nullable = true)
#  |-- mode_of_payment: string (nullable = true)
#  |-- fin_year: string (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- pan_given: string (nullable = true)
#  |-- Party: string (nullable = true)
#  |-- Type: string (nullable = true)
#  |-- field10: string (nullable = true)
#  |-- field11: string (nullable = true)
#  |-- field12: string (nullable = true)
#  |-- field13: string (nullable = true)
#  |-- field14: string (nullable = true)
#  |-- field9: string (nullable = true)

# %% [markdown]
# 4. Categorize the modes of payment into 4 categories
#
#     a. Cash
#
#     b. Cheque
#
#     c. Bank
#
#     d. Others

# %%
modes = ['Cash', 'Cheque', 'Bank', 'Others']

# %%
#add column of transformed mode of payment
from pyspark.sql.functions import lit
df2 = df2.withColumn("payment_segregated", lit(''))

# %%
from pyspark.sql.functions import when
from pyspark.sql.functions import lower, col
df2 = df2.withColumn("payment_segregated", when(lower(df2["mode_of_payment"]).contains('cash'), 'Cash').when(lower(df2["mode_of_payment"]).contains('cheque') | lower(df2["mode_of_payment"]).contains('ch.') | lower(df2["mode_of_payment"]).contains('ch no'), 'Cheque').when(lower(df2["mode_of_payment"]).contains('bank'), 'Bank').otherwise('Others'))

# %%
for rows in df2.select("mode_of_payment", "payment_segregated").collect():
    print(rows[0]," - ", rows[1])
# Out:
# Streaming output truncated to the last 5000 lines.
# 12719 Central Bank  -  Bank
# 999632 Vijaya Bank  -  Bank
# 208152 State Bank Of India  -  Bank
# 567491,Bank Of Baroda  -  Bank
# 925343  -  Others
# 28031PUNJAB & SINDH BANK, C.P., NEW DELHI-110001  -  Bank
# 00000 3, Bank of Baroda  -  Bank
# 1759049 Narmada Malwa Gramin Bank  -  Bank
# 81, Karur Vyshya Bank  -  Bank
# Cash  -  Cash
# 134457INDIAN BANK, WEST PATEL NAGAR-NEW DELHI-08  -  Bank
# 989216 Canara Bank  -  Bank
# 556725, Ing Vysya Bank  -  Bank
# 169786, Parshawrnath Bank  -  Bank
# 170133, Parshwaranath Bank  -  Bank
# 8760, IDBI Bank  -  Bank
# 790920, HDFC Bank _x000D_
# _x000D_
# Ltd  -  Bank
# 270162 State Bank of India  -  Bank
# 162362 State Bank Of India  -  Bank
# 725881, Indian Overseas Bank  -  Bank
# 634160 Central Bank  -  Bank
# 398300PUNJAB NATIONAL BANK  -  Bank
# 040877, Cosmos Bank  -  Bank
# 372958, JK Bank Bari Brahmna Jammu  -  Bank
# 337224, HDFC Bank  -  Bank
# 726552, HDFC Bank  -  Bank
# 726553, HDFC Bank  -  Bank
# 952344, Indusind Bank  -  Bank
# 952343, Indusind Bank  -  Bank
# Cheque No.860922 Punjab National Bank  -  Cheque
# CHEQUE, State Bank of Patiala  -  Cheque
# 30939,  IDBI Bank, Prabhadevi Branch  -  Bank
# 7821 Union Bank of India  -  Bank
# Cash  -  Cash
# 999945, Mehsana Urban Co-op Bank  -  Bank
# 504470SYNDICATE BANK, AMBEDKAR NAGAR-N.D.-62  -  Bank
# 66115, Dena Bank  -  Bank
# 015550, State Bank of India  -  Bank
# 701197 State Bank Of India  -  Bank
# 306702  STATE BANK OF PATIALA, ROHINI, DELHI-85  -  Bank
# Cash  -  Cash
# 117792  -  Others
# 00 2481,  Kotak Mahindra Bank, Villeparle(W) Branch  -  Bank
# 6965 HDFC Bnak Ltd  -  Others
# Ch No- 090502, SBI, Sohagpur  -  Cheque
# 287088BANK OF MAHARASTHRA  -  Bank
# 68056 The Federal Bank Ltd  -  Bank
# 659477, Dena Bank  -  Bank
# 371182, HDFC  -  Others
# 818853, Akhand Anand Co-op Bank Ltd  -  Bank
# 116719  -  Others
# 34524, Bank of India  -  Bank
#   -  Others
# Bank Transfer  -  Bank
# S.I., SBI, PH  -  Others
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Cheque No.001719 HDFC Bank,New Delhi  -  Cheque
# Cash  -  Cash
# Cheque No 238460 Dtd. 31.05.2005 Canara Bank Panaji, Goa  -  Cheque
# 868234, Bank of Baroda  -  Bank
# Through Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# 4004,The J&K Bank  -  Bank
# 5609BANK OF INDIA, TEHRI, UTTARAKHAND-249201  -  Bank
# Onnline Trfd.  -  Others
# Cheque No. 263644 HDFC BANK  WORLI BRANCH,MUMBAI  -  Cheque
# Cheque No. 263644 HDFC BANK WORLI BRANCH,MUMBAI  -  Cheque
# 339527, Punjab National Bank  -  Bank
# 3244937,  Punjab National Bank  -  Bank
# Cheque No-677497, IDBI Bank, Chembur Branch, Mumbai  -  Cheque
# 76KOTAK MAHINDRA BANK, PUNJABI BAGH, NEW DELHI-26  -  Bank
# 887456 Union Bank of India Kandivil West Branch  -  Bank
# Ch-006290-CBI, P. Park  -  Others
# 400759,  State Bank of India  -  Bank
# Cheque No.  174015, Uco Bank Ahemdabad  -  Cheque
# 124548 BOI  -  Others
# 124547 BOI  -  Others
# 487301,  State Bank of India  -  Bank
# Ch. No. 30571/dtd.10.10.2009Saraswat Bank Grant Road 203A, Dr. D.B. Marg Mumbai-400007  -  Cheque
# 43, Bank of India  -  Bank
# 342223, State Bank _x000D_
# _x000D_
# of India  -  Bank
# 368405   State    BANK OF INDIA  -  Bank
# Through Bank Transfer  -  Bank
# S.I. SBI-PH  -  Others
# 859695 PNB  -  Others
# 983063INDIAN OVERSEAS BANK  -  Bank
# 893703 State Bank of Patiala  -  Bank
# 008660, Central Bank of India Mapusa  -  Bank
# 785183,  Syndicate Bank, Vileparle (E ) Branch  -  Bank
# 676395 SBI  -  Others
# 564682, Punjab National Bank Panaji  -  Bank
# 109662,  Punjab National Bank, Panaji  -  Bank
# 9653,  The Naroda Nagrik Co-op Bank  -  Bank
# 115,  HDFC Bank  -  Bank
# 125, HDFC Bank  -  Bank
# 147, HDFC Bank  -  Bank
# 149, HDFC Bank  -  Bank
# 107,  HDFC Bank  -  Bank
# 151, HDFC Bank  -  Bank
# 136, HDFC Bank  -  Bank
# 137, HDFC Bank  -  Bank
# 140, HDFC Bank  -  Bank
# 139, HDFC Bank  -  Bank
# 141, HDFC Bank  -  Bank
# 154, HDFC Bank  -  Bank
# 111,  HDFC Bank  -  Bank
# 134, HDFC Bank  -  Bank
# 130, HDFC Bank  -  Bank
# 000153, HDFC Bank Kasturba Gandhi Marg, New Delhi Branch  -  Bank
# 000128, HDFC Bank  -  Bank
# Ch.No.000114, Dated.26.03.2014, HDFC Bank G-3-4, Suryakiran Building 19-Kasturba Gandhi Marg  -  Cheque
# Cheque, HDFC Bank, G-3-4, Surya Kiran Building-19, New Delhi  -  Cheque
# Ch.No. 000110 otd.24 .03.2014, HDFC Bank, G-3-4, Suryakiran Building  -  Cheque
# Ch.No.000117, Dated.27.03.2014, HDFC Bank G-3-4, Suryakiran Building 19-Kasturba Gandhi Marg  -  Cheque
# Ch.No. 000003  -  Cheque
# Cheque, HDFC Bank, G-3-4, Surya Kiran Building-19, New Delhi  -  Cheque
# Cheque No- 127154/date 13-01-2012, HDFC Bank  -  Cheque
# Ch.No.127146/Dtd.05.10.2009  HDFC Bank Ltd. New Delhi  -  Cheque
# Ch.No.127148/Dtd.07.10.2009  -  Cheque
# Ch.No. 000101, HDFC Bank New Delhi  -  Cheque
# Ch.No. 000150, HDFC Bank, K.G. Marg, New Delhi, Dt. 08.10.2014  -  Cheque
# Ch No- 000105, HDFC Bank KG Marg, New Delhi  -  Cheque
# Ch.No. 000121, HDFC Bank, Suriya Kiran Bld, K.G. Marg,  New Delhi, Dt. 02.04.2014  -  Cheque
# DD.No.339647/Dated.28.04.2009, HDFC Bank Kailash Bldg, New Delhi  -  Bank
#   -  Others
# cash  -  Cash
# 20, HDFC Bank  -  Bank
# 168, Bank of Baroda  -  Bank
# 987133, State Bank of India Aurangabad Br.  -  Bank
# 962898, Kankaria Maninagar Nagarik Bank  -  Bank
# 103183, Union Bank of India  -  Bank
# 266787,Allahabad Bank  -  Bank
# 994585 SBI  -  Others
# Ch.No. 556194,SBBJ Jaipur  -  Cheque
# 00 1248,  TJSB Bank, Thane(W) Branch  -  Bank
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# S.I. SBI-PH  -  Others
# Cheque State bank of india parliament street new delhi  -  Cheque
# 742086STATE BANK OF PATIALA. ROORKEE  -  Bank
# 345313, Dena Bank  -  Bank
# Cheque No.-  926906 UCO Bank Ahmedabad  -  Cheque
# 207683UCO BANK  -  Bank
# 006481, Kotak Mahindra Bank  -  Bank
# 128354 ICICI Bank Karnavati City  -  Bank
# 930630UCO BANK  -  Bank
# 65875PNB, SHALIMAR BAGH, DELHI-110088  -  Others
# 145114 ICICI Bank  -  Bank
# 401729   State    BANK OF INDIA  -  Bank
# 59388, HDFC Bank Ltd  -  Bank
# 10937, State Bank of India  -  Bank
# 141651, State Bank of India  -  Bank
# 390138, HDFC Bank  -  Bank
# Ch. No.-330589, Dated-05-10-2010Sardar Vallabhbhai Sahkari Bank Ltd. Bank Harom Tower Panchvati Road, Law Garden Ahmedabad  -  Cheque
# 553083   HDFC BANK  -  Bank
# 879815, HDFC  -  Others
# Draft No. 924282/ Dt. 05.12.2012, Kotak Mahindra Bank Ltd Ahmedabad  -  Bank
# 916609, HDFC  -  Others
# 882816, HDFC  -  Others
# 816729  -  Others
# 92239, Bank of Baroda  -  Bank
# 442962PNB, KOLKATA-700017  -  Others
# 363520, Axis Bank Ltd  -  Bank
# 574276,  Axis Bank Ltd  -  Bank
# 938061, Punjab National Bank  -  Bank
# 896956, Punjab National Bank  -  Bank
# 314484 PNB Karnavati City  -  Others
# 847048, ICICI Bank  -  Bank
# 1078, Bank of Baroda  -  Bank
# 239718,  Kotak Mahindra Bank, Napian Sea Rd.  -  Bank
# 23212, State Bank of India  -  Bank
# 4653, HDFC  -  Others
# RTGS, SBINR120144092604028505, Dt. 26.09.2014, State Bank of India, Dt. 27.09.2014  -  Bank
# Cheque No.150961,Dated 27.10.2005 Canara Bank,Banglore  -  Cheque
# Cheque No.285292,Dated 27.10.2005 Canara Bank,Banglore  -  Cheque
# 431330, Yes Bank Andheri East, Mumbai Branch  -  Bank
# 000026, State Bank of India, Malad West  -  Bank
# 456063,  Indian Overseas Bank Panaji  -  Bank
# 22753   ICICI Bank  -  Bank
# 227436 Vidisha Bhopal Kshetriya Gramin Bank  -  Bank
# Ch.No.  / Dt. _x000D_
# _x000D_
# 30.11.2012, IDBI Bank Ltd  -  Cheque
# Cheque No. 66871 IDBI BANK,UDAIPUR  -  Cheque
# Ch. No. 217362/dtd. 23-04-2009    IDBI Bank Ltd.  -  Cheque
# 158479, State Bank of India Patna, Bihar  -  Bank
# 328250, State Bank of India Patna, Bihar  -  Bank
# 441231, State Bank of India Patna, Bihar  -  Bank
# 574712, State Bank of India Patna, Bihar  -  Bank
# 680395, State Bank of India Patna, Bihar  -  Bank
# 786844, State Bank of India Patna, Bihar  -  Bank
# 459601 Axis Bank, Defence Colony, ND  -  Bank
# 404546PUNJAB NATIONAL BANK  -  Bank
# 2227288 SIB  -  Others
# Cheque  -  Cheque
# Cheque No-  169848,UTI  Bank Fort Mumbai  -  Cheque
# Ch. No- 977266/Dated-31-01-2011  -  Cheque
# 75460CENTRAL BANK OF INDIA  -  Bank
# S.I. SBI-PH  -  Others
# Ch No 507259, Dtd 05-09-2013, SBI, Parliament House, New Delhi  -  Cheque
# Cheque No. 958260 INDIAN BANK,CHENNAI  -  Cheque
# Ch.No.975815/Dtd.09.04.2009 Indian Bank  -  Cheque
# 262997, Dena Bank  -  Bank
# 00 9516,  ICICI Bank  -  Bank
# 475351, Dena Bank  -  Bank
# 344385, Indian Bank  -  Bank
# 414389, Indian Bank  -  Bank
# 0 59228,  HDFC Bank, Chembur Branch  -  Bank
# 117297, Axis Bank  -  Bank
# 196633,  Axis Bank, Pune- 4 Branch  -  Bank
# 196635,  Axis Bank, Pune- 411001 Branch  -  Bank
# 196636,  Axis Bank, Pune- 4 Branch  -  Bank
# RTGS, UTIBH14274037024, Dt. 01.10.2014, Axis Bank Ltd Pune, Dt. 04.10.2014  -  Bank
# Ch No 117199 Date 12-03-2014, Axis Bank Ltd. Pune-4  -  Cheque
# Ch.No. 117277, Dt. 28.04.2014, Axis Bank Ltd Pune, Dt. 30.04.2014  -  Cheque
# Ch No 196509, Date 02-01-2014, Axis Bank Ltd, Pune  -  Cheque
# Cheque No.  362506, Canara Bank Panaji  -  Cheque
# Bank Transfer RTGS, ICICI Bank Limited Panaji Branch  -  Bank
# Ch.No.548287/Dtd.15.04.2009Canara Bank Panaji, Goa  -  Cheque
# Cheque No, Canara Bank Panaji Goa  -  Cheque
# Cheque No-   Canara Bank  Panaji Goa  -  Cheque
# Cheque No 913411 Dtd 20.02.2006 Canara Bank Mapusa, Goa  -  Cheque
# Cheque Canara Bank Panaji  -  Cheque
# 202831   ICICI Bank  -  Bank
# 000179, HDFC Bank Ltd _x000D_
# _x000D_
# Panaji  -  Bank
# 238464 Canara Bank, Panaji  -  Bank
# CHEQUE NO. 913853 CANARA. BANK. PANAJI  -  Cheque
# Cheque No.  364369, Canara Bank Panaji  -  Cheque
# Cheque  HDFC bank panaji  -  Cheque
# Cheque  Canara bank panaji  -  Cheque
# Cheque  Canara bank panaji  -  Cheque
# 042277 ICICI Bank Ltd.  -  Bank
# Cheque No.-  893723 Canara Bank Panaji  -  Cheque
# 041450 ICCI Bank Ltd.Panji  -  Bank
# Chaque No 541344 Canara Bank Panaji  -  Bank
# 2036, Bank of Baroda  -  Bank
# 2037, Bank of Baroda  -  Bank
# 767446,  Dena Bank, Sharebazar Branch  -  Bank
# Cheque No.  000724,UTI  Bank New Delhi  -  Cheque
# 806523  -  Others
# Cheque No.871674State Bank of India  -  Cheque
# 352613  SBI  -  Others
# Cheque No.154193  -  Cheque
# Ch.No.680725/Dtd.03.04.2009 Andhra Bank,Sanathnagar, Hyderabad  -  Cheque
# Ch.No.485110/Dtd.03.04.2009 SBH Industrial Finance Branch, Hyderabad  -  Cheque
# Ch.No.149706/dated.03.10.2009Axis Bank Ltd. Begumpet, Hyderabad (AP)  -  Cheque
# Ch.No.506864/dated.04.02.2010Axis Bank Ltd. Begumpet, Hyderabad (AP)  -  Cheque
# Cheque No.352593,Dated 21.03.2009SBI Greater Kailash,New Delhi  -  Cheque
# 001844, PMC Bank Caranzalem  -  Bank
# 107826 State Bank Of India  -  Bank
# 215491   IDBI Bank  -  Bank
# 373163SARDAR BHILAWALA CO.OP  -  Others
# 56129     BANK OF INDIA  -  Bank
# 52018Bank of Baroda  -  Bank
# 220      BANK OF INDIA  -  Bank
# Cheque No.46780 Delhi Nagrik Sahakari Bank  -  Cheque
# 746095   ICICI Bank  -  Bank
# 941970   State    BANK OF INDIA  -  Bank
# 642652       Axis Bank  -  Bank
# 363476SARDAR BHILAWALA CO.OP  -  Others
# 229611   State    BANK OF INDIA  -  Bank
# 445666  SARDAR BHILAWALA CO.OP  -  Others
# 133496  SARDAR BHILAWALA CO.OP  -  Others
# 45667  SARDAR BHILAWALA CO.OP  -  Others
# 133497SARDAR BHILAWALA CO.OP  -  Others
# 145339BANK OF INDA  -  Bank
# 87757BANK OF INDA  -  Bank
# 272229DEVLOPMENT OF BANK  -  Bank
# Cash  -  Cash
# 169029   HDFC Bank  -  Bank
# 959166   HDFC Bank  -  Bank
# 454637   State    BANK OF INDIA  -  Bank
# Cheque No747576 Dtd 22.03.2006 Andhra Bank Andhra Bhawan New Delhi  -  Cheque
# 734787   State    BANK OF INDIA  -  Bank
# 518299   ICICI Bank  -  Bank
# 518298   ICICI Bank  -  Bank
# 100926   State    BANK OF INDIA  -  Bank
# 546664   IDBI Bank  -  Bank
# 408YES BANK  -  Bank
# 352994  SARDAR BHILAWALA CO.OP  -  Others
# 352996  SARDAR BHILAWALA CO.OP  -  Others
# 356744   Central    BANK OF INDIA  -  Bank
# Cheque No.-  332446, 45 Corporation Bank Narela ND  -  Cheque
# 691695   IDBI Bank  -  Bank
# 668476   ICICI Bank  -  Bank
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No 221085 Dtd 27.12.2005 State Bank Of India Parliamint House  -  Cheque
# S.I. -SBI-PH  -  Others
# Ch.No. 004503-ICICI Bank S.Ex. II  -  Cheque
# S.I. -SBI-PH  -  Others
# Ch.No. 022894-SBI-PH  -  Cheque
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# Cheque No.271484 HDFC Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# Bank Transfer  -  Bank
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.516739 Punjab & Sindh Bank  -  Cheque
# Cheque No 450346 State Bank Of India Keshavpuram New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No 757726 Dtd 18.1.2006 State Bank Of India Parliamint House  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.413884,Dated 28.10.2005 State Bank of India,HCS,Chandigarh  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.385942 Punjab & Sindh Bank  -  Cheque
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# Cheque No.244970 HDFC Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# 1014  KOTAK MAHINDRA BANK  -  Bank
# S.I. -SBI-PH  -  Others
# Cheque No 993055 Dtd.23.05.2006State Bank Of India Parilament House New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.174415,Dated 18.11.2005  State Bank of India,Parliament House,New Delhi-1  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.316481 State Bank of India  -  Cheque
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# Cheque No-  27767   Date 03.10.2008The Laksmi Vilas Bank  -  Cheque
# Cheque No 995259 Dtd 21.12.2005 State Bank Of India Parliamint House  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# Cash  -  Cash
# Cheque No.200577,Dated 18.10.2005 ABN Amro Bank,Gurgaon  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.326228,Dated 17.06.2005Bank of Maharashtra,Mumbai  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.337393,Dated 11.11.2005 Cooperation Bank,Banglore  -  Cheque
# Cheque No.707656,Dated 27.10.2005 Canara Bank,Mumbai  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.174145State Bank of India  -  Cheque
# Cheque No. 611250 BANK OF RAJASTHAN,JAIPUR  -  Cheque
# Cheque No.49842 United Bank of India  -  Cheque
# S.I. -SBI-PH  -  Others
# Out Standing  -  Others
# Cheque No.976088 Syndicate Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# 103729   IDBI Bank  -  Bank
# 103730   IDBI Bank  -  Bank
# S.I. -SBI-PH  -  Others
# Cheque No. 195297 SBI,SANSAD MARG,NEW DELHI  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.715107 Bank of Baroda  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Out Standing  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.537328 Bank of Baroda  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# Cheque No.448941 Bank of Baroda  -  Cheque
# S.I. -SBI-PH  -  Others
# Out Standing  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# Cheque No.557258,Dated 13.12.2005  Delhi State Coop. Bank Ltd.New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.690184,Dated 17.12.2005 State Bank of India,New Delhi,Parliament House  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No-  497100    Date 04.08.2008SBI, Bhopal  -  Cheque
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# 802373, Axis Bank, Gurgaon  -  Bank
# S.I. -SBI-PH  -  Others
# 461932, Indian Overseas Bank  -  Bank
# S.I. -SBI-PH  -  Others
# Ch.No. 741172, 147803, UCO Bank .S Court  -  Cheque
# Cheque No.968441 Bank of Rajasthan Ltd.Pali  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# 283, Bank of India Chd.  -  Bank
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# 377151  CENTRAL BANK OF INDIA  -  Bank
# Cheque No. 799119 PNB JAIPUR  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.090206,Dated 05.12.2005 Bank of Baroda  -  Cheque
# Ch.No. 966792- Canara Bank Dip. Enclv.  -  Cheque
# S.I. -SBI-PH - PHA  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.132768,Dated 10.11.2005 Vysya Bank Ltd.,Banglore  -  Cheque
# Cash  -  Cash
# Cheque No.749996Standard Chartered Bank  -  Cheque
# Cheque No 176154 Dtd 23.12.2005 State Bank Of India Parliamint House  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. SBI, Mayapur Ind Area  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.180562 Punjab & Sindh Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# 064029, UBI, _x000D_
# _x000D_
# Manesar, Gurgaon  -  Others
# S.I. -SBI-PH  -  Others
# Ch. No. 465630-SBI-PH  -  Cheque
# Cheque No.767716 Punjab & Sindh Bank  -  Cheque
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Out Standing  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# Cheque No 886720 Dtd 9.01.2006 State Bank Of India Parliamint House  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.105015 Central Bank of India  -  Cheque
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.987452,Dated 21.04.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.990189,Dated 22.12.2005 State Bank of India,New Delhi,Parliament House  -  Cheque
# S.I. -SBI-PH  -  Others
# Ch. No. 809643-SBI-PH  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# 457959  -  Others
# 39154, HDFC Bank  -  Bank
# Cheque No.434087 State Bank of India  -  Cheque
# 31195     ICICI Bank  -  Bank
# Cash  -  Cash
# Cheque No.270635 Indian Overseas Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No 237668 Dtd 10.09.2005 Vijaya Bank Port Blair  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque State Bank of Patiala  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.496079  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.829976,Dated 19.12.2005 State Bank of India,New Delhi,Parliament House  -  Cheque
# S.I. -SBI-PHA  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.447358 State Bank of India  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.665826,Dated 25.10.2005 Syndicate Bank,New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# 366989, State Bank of _x000D_
# _x000D_
# India, Narainagarh  -  Bank
# 985508  -  Others
# Cheque No.977956,Dated 28.12.2005 State Bank of India,New Delhi,Parliament House  -  Cheque
# Out Standing  -  Others
# Out Standing  -  Others
# Cheque No. 565465 BANK OF RAJASTHAN,JAIPUR  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# Cash  -  Cash
# Cheque No.082469 IDBI Bank  -  Cheque
# 449115  -  Others
# S.I. -SBI-PH  -  Others
# Ch.No.152153-SBI-PH, Adv. Pymnt  -  Cheque
# Cheque No. 110574 INDUSLAND BANK,CHANDIGARH  -  Cheque
# Cheque No. 110575 INDUSLAND BANK,CHANDIGARH  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Out Standing  -  Others
# Ch.No. 314080-SBI-PH  -  Cheque
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.484191,Dated 12.09.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Ch.No. 106434-CBI, P. Park  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.220817 Punjab National Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.017448  SBBJ,V.K.I.,Jaipur  -  Cheque
# S.I. -SBI-PH  -  Others
# Out Standing  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.062831 State Bank of India  -  Cheque
# Out Standing  -  Others
# Cheque No.040260 Union Bank of India  -  Cheque
# Cheque No.721630 State Bank of India  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.213684 Union Bank of India  -  Cheque
# Cash  -  Cash
# Cash  -  Cash
# Cheque No.524884 Corporation Bank  -  Cheque
# 14172 Kotak Mahindra Bank, New Delhi  -  Bank
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# Cheque No.467833,Dated 05.11.2005  State Bank of India,Banglore  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.478108 Bank of Rajasthan Ltd  -  Cheque
# Cheque No.468838 Indian Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.616326  ICICI Bank,C-Scheme,Jaipur  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No989624 Dtd 27.03.2006 State Bank Of India Parliamint House  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH & Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# Draft No 479277 Dtd. 22.03.2006Andhra Bank Cannaught Cirus, New Delhi  -  Bank
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.993776,Dated 04.10.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.757726,Dated 18.01.2006 State Bank of India,New Delhi,Parliament House  -  Cheque
# Cheque No.920457 Syndicate Bank  -  Cheque
# Cash  -  Cash
# Cheque No.850473,Dated 08.11.2005 Citi Bank,New Delhi  -  Cheque
# Cash  -  Cash
# DD. No.419709,Dated 31.10.2005  Vijaya Bank,New Delhi  -  Bank
# Cheque No.489386,Dated 09.06.2005 Vijaya Bank,Secundrabad,Andhra Pradesh  -  Cheque
# Cheque No.181342,Dated 30.09.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.849481 Bank of Baroda  -  Cheque
# Cash  -  Cash
# Cheque No.523293,Dated 05.04.2005 Bank of Baroda,Surat  -  Cheque
# Cheque No.578177,Dated 26.10.2005 ICICI Bank,New Delhi  -  Cheque
# Cheque No.988315,Dated 23.12.2005 State Bank of India,New Delhi,Parliament House  -  Cheque
# Cheque No.186293,Dated 26.05.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.979759,Dated 04.10.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.255015 State Bank of Maharashtra  -  Cheque
# Cheque No.917181 Oriental Bank of Commerce  -  Cheque
# Cheque No.995451,Dated 16.09.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.668419,Dated 15.09.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.148622,Dated 22.12.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.978293,Dated 12.09.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.460054,Dated 03.03.2006 State Bank of India,New Delhi,Parliament House  -  Cheque
# Cheque No.524337,Dated 24.10.2005 Syndicate Bank,New Delhi  -  Cheque
# Cheque No.729414,Dated 02.06.2005 Andhra Bank,A.P.Bhawan,New Delhi  -  Cheque
# Cheque No.179370,Dated 07.09.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# Cheque No.989022,Dated 03.10.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.178576,Dated 17.05.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cash  -  Cash
# Cheque No.202098 Bank of Baroda,Service Branch,New Delhi  -  Cheque
# Cheque No.171851,Dated 16.06.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.171584,Dated 15.05.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.176154,Dated 23.12.2005 State Bank of India,New Delhi,Parliament House  -  Cheque
# Cheque No.229015,Dated 31.08.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.072140,Dated 25.06.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.223004,Dated 27.10.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.201143,Dated 16.08.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.983446,Dated 04.06.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.560612,Dated 07.11.2005 Karnataka State Coop. Bank Ltd.,Banglore  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.224814,Dated 18.05.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cash  -  Cash
# Cheque No.978606,Dated 17.05.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cash  -  Cash
# S.I. -SBI-PH  -  Others
# S.I. -SBI-PH  -  Others
# Cheque No.047040 UCO Bank,Beelwa  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque No.193698 Bank of Baroda,Mansarovar,Jaipur  -  Cheque
# Cheque No.538877,Dated 04.10.2005   Corporation Bank,New Delhi  -  Cheque
# Cheque No.437497,Dated 22.02.2005 Bombay Mercantile Coop. Bank Ltd. Surat  -  Cheque
# Cheque No.437497,Dated 22.02.2005 Bombay Mercantile Co.  -  Cheque
# Cheque No.994391,Dated 17.12.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.128470,Dated 02.01.2006 State Bank of India,New Delhi,Parliament House  -  Cheque
# Cheque No.174382,Dated 15.12.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.199154,Dated 29.06.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No 994302 Dtd 19.12.2005 State Bank Of India Parliamint House  -  Cheque
# S.I. -SBI-PH  -  Others
# Cheque  -  Cheque
# Cheque No.132768,Dated 10.11.2005 Karnataka State Coop. Bank Ltd.,Banglore  -  Cheque
# Cheque No.781096,Dated 22.11.2005 Punjab National Bank,Mahrauli Road,H.Khas,New Delhi  -  Cheque
# Cheque No.178839,Dated 08.08.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.178844,Dated 13.12.2005 State Bank of India,Parliament House,New Delhi-1  -  Cheque
# Cash  -  Cash
# Cheque No.942007 Standard Chartered Bank  -  Cheque
# Cheque No.173448,Dated 26.09.2005  State Bank of India,Parliament House,New Delhi  -  Cheque
# Cash  -  Cash
# Cash  -  Cash
# Cheque No.529863,Dated 22.10.2005 State Bank of  India Parliament House,New Delhi-1  -  Cheque
# Cheque No.379887 Punjab National Bank  -  Cheque
# S.I. -SBI-PH  -  Others
# Cash  -  Cash
# Cheque No.986952,Dated 24.05.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# Cheque No.980668,Dated 27.05.2005 State Bank of India,Parliament House,New Delhi  -  Cheque
# 7458, Indian Bank  -  Bank
# 411148, ICICI Bank  -  Bank
# Cheque No- 704376  -  Cheque
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# Out Standing  -  Others
# Cheque Punjab national bank vivek vihar delhi  -  Cheque
# Cheque  -  Cheque
# 000 132,  Bank of India, Mulund (E ) Branch  -  Bank
# 188469, Ing Vaishya Bank  -  Bank
# 845255, Ing Vaishya Bank Ltd  -  Bank
# 788375  -  Others
# Cheque No. 488200 SYNDICATE BANK FORT BRANCH,MUMBAI  -  Cheque
# 235889,  Union Bank of India, Malad  (E ) Branch  -  Bank
# 235888,  Union Bank of India, Malad  (E ) Branch  -  Bank
# Cheque No. 42290 ABHYUDAYA CO. BANK MALAD BRANCH,MUMBAI  -  Cheque
# 107042,  Union Bank, Malad(East) Branch  -  Bank
# 1967, Bank of _x000D_
# _x000D_
# India  -  Bank
# 871771INDUSIND BANK  -  Bank
# 725425, Ranuja Nagarik Bank  -  Bank
# RTGS  -  Others
# 82752, The Cosmas Co Bank Ltd.  -  Bank
# 298667, State Bank of India  -  Bank
# 001481, Bank of Baroda  -  Bank
# 958539, Indian Oversease Bank  -  Bank
# 911699, State Bank of India  -  Bank
# 347653, Yes Bank  -  Bank
# 81726 SBI  -  Others
# Onnline Trfd.  -  Others
#   -  Others
# 958519, Indian Overseas Bank  -  Bank
# 94291 J & K Bank  -  Bank
# Cash  -  Cash
# Ch.NO.-482846Canara Bank Srirampuram Branch Bangalore  -  Cheque
# Cash  -  Cash
# 49828,  State Bank of Mysore  -  Bank
# 540304, State Bank of Mysore  -  Bank
# 540303,State Bank Of Mysore  -  Bank
# 585162 State BANK Of Mysore  -  Bank
# 585163 State Bank Of Mysore  -  Bank
# 585163 State Bank Of Mysore  -  Bank
# 586965 State Bank Of Mysore  -  Bank
# 586966 State Bank Of Mysore  -  Bank
# 586967 State Bank Of Mysore  -  Bank
# 540301 State Bank Of Mysore  -  Bank
# 540302 State Bank Of Mysore  -  Bank
# 543030 State Bank Of Mysore  -  Bank
# 540393,State Bank Of Mysore  -  Bank
# 264, Bank of Baroda  -  Bank
# 516156, Bank of Baroda  -  Bank
# 362612, Oriental Bank of Commerce  -  Bank
# 380860, Oriental Bank of Commerce  -  Bank
# 360308, the Surat Nagarik Sahakari Bank  -  Bank
# 52672, Prime Co-op Bank  -  Bank
# State Bank Of India Parliament House _x000D_
# _x000D_
#   -  Bank
# Bank transfer  -  Bank
# Ch. No- 125163/Dated-18-01-2011  -  Cheque
# Bank Transfer  -  Bank
# SBI Parliament House  -  Others
# 461691SBI, REWA, M.P.  -  Others
# 6130, Bank of India  -  Bank
# Cheque No.-  951243 SBI Old MLA Quarters,Hyderabad  -  Cheque
# 000 551,  Bank of Baroda, Mumbai Main Office  -  Bank
# 00000 4,  Kotak Mahindra Bank  -  Bank
# 00000 3,  Kotak Mahindra Bank  -  Bank
# 001493, Bank of Baroda  -  Bank
#   -  Others
# Onnline Trfd.  -  Others
# cash  -  Cash
# Cheque No.524914 State Bank of Indore  -  Cheque
# 00005, HDFC Bank  -  Bank
# Cash, Collection
# Contributions  -  Cash
# Cash  -  Cash
# Cheque  -  Cheque
# Cash  -  Cash
# CASH  -  Cash
# CASH  -  Cash
# CASH  -  Cash
# Cash  -  Cash
# Cheque  -  Cheque
# Cheque, Collection Contributions  -  Cheque
# Cheque, Party Fund Collection  -  Cheque
# Cash, Party Fund Collection  -  Cash
# 334, Bank of Baroda  -  Bank
# 333,  Bank of Baroda  -  Bank
# 335, Bank of Baroda  -  Bank
# 1611  -  Others
# 662657,  State Bank of India  -  Bank
# 324543 Ing vysa Bank Surat  -  Bank
# 39146 SBI  -  Others
# 300239,  State Bank of India  -  Bank
# 487001 Almora Urban Co-perative. Bank  -  Bank
# Ch.No. 426710, SBBJ Jaipur  -  Cheque
# 429119 M.P.Rajya Sahkari Bnak  -  Others
# 386168 Canara Bank  -  Bank
# 386167 Canara Bank  -  Bank
# Cheque No.034604,Dated 14.11.2005 HSBC Bank,New Delhi  -  Cheque
# Bank Transfer  -  Bank
# Cash  -  Cash
# 531681,  State Bank of India  -  Bank
# 392,  Union Bank of India  -  Bank
# 15692,  Union Bank of India  -  Bank
#   -  Others
# 339289,  SBI-Parliamentry  -  Others
# Through Bank Transfer  -  Bank
# 11458, Bank of Baroda  -  Bank
# S.I. SBI-PH  -  Others
# Through Bank Transfer  -  Bank
# 158912,  Corporation Bank, Panaji  -  Bank
# 00 1725, Kotak Mahindra Bank Panaji Branch  -  Bank
# 00 1774, Kotak Mahindra Bank Panaji Branch  -  Bank
# 00 1601,  Kotak Mahindra Bank Opp, Azad  -  Bank
# RTGS  -  Others
# 464505,  Dena Bank  -  Bank
# Ch.No. 838607, SBBJ Jaipur  -  Cheque
# 216760,  Axis Bank  -  Bank
# Cheque No. 417244PUNJAB NATIONAL BANK PUNJAB NATIONAL BANK  -  Cheque
# 1110, Bank _x000D_
# _x000D_
# of Baroda  -  Bank
# 504179 State Bank Of India  -  Bank
# Cheque, Party Fund  -  Cheque
# 492679, Andhra Bank  -  Bank
# 106673, Bank of India Stock Exchange Br.  -  Bank
# 69729, State Bank of India  -  Bank
# 624231, Sarvodaya Shakari Bank  -  Bank
# 72550, Bank of India  -  Bank
# 25266, Deutsche Bank  -  Bank
# The Gandhidham Mercantile Co-op  -  Others
# DD749382 Dt. 1/12/12 Indian Bank Vima Kamaghar Sangatana, MDO IV  -  Bank
# 815377 Uco bank  -  Bank
# 280420, State Bank of India  -  Bank
# 32925, State Bank of India  -  Bank
# 363576, State Bank of India  -  Bank
# 105351, State Bank of India  -  Bank
# 177519,  Saraswat Bank of India, Powai Branch  -  Bank
# 1876  -  Others
# Cheque No 58552 Vijaya Bank  -  Cheque
# Cheque, HDFC Bank Pune  -  Cheque
# 13551  IQB, PASCHIM VIHAR, NEW DELHI-110063  -  Others
# 502668 Bank of Baroda  -  Bank
# DD. NO.- 277598/Dated- 20-04-2010Canara Bank Qutub Institutional Area New Delhi  -  Bank
# 662630SBI, RAIPUR, CHHATTISGARH-492001  -  Others
# 601482,  Axis Bank  -  Bank
# 15783ICICI BANK, CHANDANI CHOWK,DELHI-110006  -  Bank
# 989999Canara Bank  -  Bank
# Bank Transfer  -  Bank
# Ch No 854114 Dtd 17-02-2014, SBI Parliament House, New Delhi  -  Cheque
# Bank Transfer  -  Bank
# 53302 Axis Bank  -  Bank
# Cheque, ICICI Bank Thaltej Br  -  Cheque
# 000209, Bank Marzaban Road, Mumbai Br.  -  Bank
# 292531,  HDFC Bank, Bandra � Br.  -  Bank
# 717350, Indian Bank  -  Bank
# S.I. SBI-PH  -  Others
# Bank Transfer,  SBI-Parliamentry  -  Bank
# 31053,  Nutunnagrik Sahakari Co-op Bank  -  Bank
# 34143, Nutunnagrik Sahakari Co-op Bank  -  Bank
# 4227 Union Bank  -  Bank
# Cheque No.  017824, The Vijay Co-Op Bank Ltd Ahmedabad  -  Cheque
# 975, The Vijay Co-op Bank  -  Bank
# Cheque No 989722 Bank Of Baroda Sultanpuri, Mazra  -  Cheque
# Cheque No. 137376 THE HSBC BANK THE HSBC BANK  -  Cheque
# 173, Kotak Mahindra Bank  -  Bank
# 174342, Bank of India  -  Bank
# 001856, Kotak Mahindra Bank Ahmedabad Br.  -  Bank
# 208912 The J&k Bank  -  Bank
# 143803, Axis Bank _x000D_
# _x000D_
# Ltd  -  Bank
# 965677 ICICI Bank, Panaji  -  Bank
# 000 248,  HDFC Bank Panaji  -  Bank
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# 214611  ANDHARA BANK, ROHINI, NEW DELHI-110085  -  Bank
# 549364, 120700SBI, LODHI ROAD, NEW DELHI-110003, AXIS BANK, DEFENCE COLONY NEW DELHI-110024  -  Bank
# Cash  -  Cash
# 558691PNB  -  Others
# 00 2518,  HDFC Bank, Yashodham Branch  -  Bank
# 340993, HDFC Bank  -  Bank
# Cheque  -  Cheque
# Cheque  -  Cheque
# 437344 Canara Bank  -  Bank
# 49795,  Union Bank of India  -  Bank
# 949343, Indian Bank  -  Bank
# 949274, Indian Bank  -  Bank
# 570749, Union Bank of India Rey Road Mumbai Br.  -  Bank
# Cash  -  Cash
# 56004, HDFC  -  Others
# 82449, South Indian Bank  -  Bank
# Cheque No 614379 Dtd 27.09.2005  ICICI Bank Ltd. Banglore  -  Cheque
# Cheque No 522936 Dtd. 12.12.2006State Bank Of India Parilament House New Delhi  -  Cheque
# Cheque No-  36208  Date 27.02.2009State Bank of India  -  Cheque
# Cheque No 171861 Dtd  30.08.2006State Bank Of Bank New Delhi  -  Cheque
# Cheque No 938796 Dtd. 20.12.2006Syndicate Bank Bangalore  -  Cheque
# 44253, Surat Peoples Co-op Bank  -  Bank
# 779397, Bank of Maharashtra Deccan Gymkhana Br.  -  Bank
# Cheque, Bank of Maharashtra Deccan Gyamkhana Pune  -  Cheque
# Ch No- 779388 Date 30-3-2014, Bank of Maharashtra  -  Cheque
# 134813, IDBI Bank, Malad West Branch  -  Bank
# 474491PUNJAB NATIONAL BANK  -  Bank
# 131240, ICICI Bank  -  Bank
# 24,  Bank of Baroda  -  Bank
# 1383, Bank of India  -  Bank
# Cheque  -  Cheque
# Cash  -  Cash
#   -  Others
# 420197, State Bank of India  -  Bank
# 121931, Dena Bank  -  Bank
# 140853SBI, RUDRAPUR, UTTARANCHAL-263153  -  Others
# Cash  -  Cash
# 7551 Statae Bank Of Bikaner & Jaipur  -  Bank
# Cheque No- 468448,dt-07.12.2004S.B. mysore punjabi bagh new delhi  -  Cheque
# 581048,  Indian Bank, JVPD Juhu Branch  -  Bank
# 112887, ICICI Bank  -  Bank
# cash  -  Cash
# 710603,  State Bank of India  -  Bank
# 180314 State Bank of India. Panaji  -  Bank
# 726500, South Indian Bank  -  Bank
# Cash  -  Cash
# 364, HDFC Bank  -  Bank
# Cheque No. 388797 BANK OF INDIA  -  Cheque
# Ch. No.-658878Central Bank Kamalanagar Branch Bangalore  -  Cheque
# Cheque No.-  998961 The Commercial Co-op Bank Ahnedabad  -  Cheque
# NEFT, HDFC Bank  -  Bank
# 534766,  Oriental Bank of Commerce Mandvi Branch  -  Bank
# DD. No- 736199, Dated-30-07-2010State Bank of Patiala, Gokhle Road Mumbai  -  Bank
# cash  -  Cash
# 258383, Allahabad Bank  -  Bank
# 306911, _x000D_
# _x000D_
# Sankheda Nagarik Sahakari Bank  -  Bank
# 263819, Allahabad Bank  -  Bank
# 289675, Allahabad Bank  -  Bank
# 126407 State Bnak Of Travancore  -  Others
# 208054, Saraspur Nagrik co-op Bank  -  Bank
# 109165, Central Bank of India  -  Bank
# 219432, Indusind Bank  -  Bank
# 748017, Bank of Baroda  -  Bank
# 219434, Indusind Bank  -  Bank
# 2807059, Dena Gujarat Gramin Bank  -  Bank
# 2807058, Dena Gujarat Gramin Bank  -  Bank
# 37851, Rajkot Nagarik Sahkari Bank Ltd.  -  Bank
# 129686, Axis Bank  -  Bank
# 038108, Dena Bank  -  Bank
# 773538, The Varachha Co-op Bank Ltd  -  Bank
# 773539, The Varachha Co-op Bank Ltd  -  Bank
# 436000, Syndicate Bank  -  Bank
# 12178, Baroda Gujarat Gramin Bank  -  Bank
# 852880, Oriental Bank of Commerce  -  Bank
# 266610,  Allahabad Bank  -  Bank
# 242273, State Bank of India  -  Bank
# 289140, Syndicate Bank  -  Bank
# 356776 HDFC  -  Others
# 990129,  HDFC Bank, Matunga Branch  -  Bank
# 506373  -  Others
# 312577, Allahabad Bank  -  Bank
# 27845 Cosmos Bank  -  Bank
# 94140, Oriental Bank of Commerce  -  Bank
# 358170, Union Bank  -  Bank
# cash  -  Cash
# Bank Transfer,  SBI-Parliamentry  -  Bank
# Cash  -  Cash
# 975456, Vanara Bank  -  Bank
# 656520  -  Others
# 244620, A.D.C. Bank  -  Bank
# Cheque No.  726995 Bank Of India Ahmedabad  -  Cheque
# 800756, _x000D_
# _x000D_
# Indian Bank  -  Bank
# Ch.N0.637585, UCO Bank, Pension, Bada, Raipur  -  Cheque
# 239925, HDFC Bank  -  Bank
# RTGS  -  Others
# 188628 State Bank Of India  -  Bank
# 503803SBI  -  Others
# Bank Transfer,  SBI-Parliamentry  -  Bank
# Ch.No.107012, SBl, Rajnandgaon  -  Cheque
# Cheque No.  20548, Oriental Bank Of Commerce Panaji  -  Cheque
# Chaque No 851074 HDFC Bank Bank Bank Panaji  -  Bank
# 521083 State Bank Of India, Mumbai  -  Bank
# 374, Bank of Baroda  -  Bank
# 1504 Bank of Baroda  -  Bank
# 454755,  Corporation Bank, Large Corporation Branch  -  Bank
# 955789DENA Bank  -  Bank
# 848868 Bank of Baroda  -  Bank
# 400231 B.N S.B  -  Others
# 006861 IDBI  -  Others
#   -  Others
# 132275 HDFC Bank  -  Bank
# 274733.34 UTI bank  -  Bank
# 836402 UTI Bank Banglore  -  Bank
# 834108  -  Others
# Cheque No-  087580,UTI  Bank Ltd Banglore Main M.G. Road Block A Banglore  -  Cheque
# 434076 Allahabad Bank  -  Bank
# Cash  -  Cash
# 153233, Godavari Urban Co-op Bank, NMC Bldg., Pandit Colony, Nasik  -  Bank
# 541, Axis Bank Ltd.  -  Bank
# 406852 Bank of India  -  Bank
# 357655,  State Bank of India  -  Bank
# 607866, State Bank of India  -  Bank
# 735204, ICICI Bank, Santa Cruz Branch  -  Bank
# 389451, Punjab National Bank  -  Bank
# 513363, Mehsana Dist. Co-op Bank  -  Bank
# 376882, Syndicate Bank  -  Bank
# 275010, Sardar Vallabhbhai Bank  -  Bank
# Cheque No.  21424, Oriental Bank Of Commerce Panaji  -  Cheque
# 3925, Bank of Baroda  -  Bank
# 25867 PNB  -  Others
# cash  -  Cash
# 171416,  The _x000D_
# _x000D_
# Ahmedabad Dist Co-op Bank  -  Bank
# 2783140, Dena Bank  -  Bank
# 500226, Bank of Baroda  -  Bank
# 973453,  Indian Overseas Bank  -  Bank
# 906625, HDFC  -  Others
# 93310, Dena Bank  -  Bank
# 470640, State Bank of India  -  Bank
# Cheque No. 888317 BANK OF BARODA BORIVALI (W) BRANCH,MUMBAI  -  Cheque
# Cheque No. 924726BANK OF BARODA BORIVALI (W) BRANCH,MUMBAI  -  Cheque
# 000333, Kotak Mahindra Bank, Powai Branch  -  Bank
# 768283, Canara Bank  -  Bank
# 7, The Vijay Co-op Bank  -  Bank
# 362370, Rajkot Dist. Bank  -  Bank
#   -  Others
# 586287,State Bank of India  -  Bank
# 185062, State Bank of India  -  Bank
# 226269, Kankaria Maninagar Bank  -  Bank
# 239296, State Bank of India  -  Bank
# 846112, Axis Bank  -  Bank
# 9308, HDFC Bank  -  Bank
# 137957, Indian Overseas Bank  -  Bank
# 141990, Indian Overseas Bank  -  Bank
# 4, Bank of Baroda  -  Bank
# 712860, HDFC  -  Others
# 503109, HDFC Bank  -  Bank
# 371958,  Karnataka Bank, Mulund(W)  -  Bank
# 64195, Navsarjan Co-Op Bank  -  Bank
# 432210, Axis Bank  -  Bank
# 67652, The Kalol _x000D_
# _x000D_
# Nagarik Sahakari Bank  -  Bank
# 960487, Punjab National Bank  -  Bank
# 892129  -  Others
# 318993, HDFC Bank  -  Bank
# 591876  SBI  -  Others
# 001181, HDFC Bank  -  Bank
# CHEQUE NO. 702777 HDFC BANK  -  Cheque
# 976559, Citi Bank  -  Bank
# 116519, The Thasara Peoples Co-op Bank  -  Bank
# Cheque No. 258256 HDFC BANK FORT BRANCH,MUMBAI  -  Cheque
# 36337, HDFC Bank  -  Bank
# Cheque, Kotak Mahindra Bank, 5c/li, Ground Floor Mittal Court 224, Nariman Point Mumbai  -  Cheque
# Ch.No. 015741, Dt. 04.01.2014, Kotak Mahindra Bank Nariman Point, Mumbai, Dt. 14.10.2014  -  Cheque
# 61252, The Godhra City Co-op Bank  -  Bank
# 330604SARDAR VALLABHAI BANK  -  Bank
# 559182, The Kalupur Com. Co-op Bank  -  Bank
# Cheque No.  682449, Standard Chartered Bank, Ahemdabad  -  Cheque
# Ch.No. 742270/Dt. 12.12.2012, The Kalupur Co.Op Bank Ltd Ashram Road Br.  -  Cheque
# 119652, State Bank of India  -  Bank
# 827262, Indusind Bank  -  Bank
# 531, The Mehsana Urbanco-op Bank  -  Bank
# 141712, State Bank of India  -  Bank
# 685205, Baroda Gujrat Gramin _x000D_
# _x000D_
# Bank  -  Bank
# 284254, State Bank of India  -  Bank
# 969745, State Bank of India  -  Bank
# 969746, _x000D_
# _x000D_
# State Bank of India  -  Bank
# 178509, Bank of Baroda  -  Bank
# 624615, State Bank _x000D_
# _x000D_
# Of India  -  Bank
# 226739, The Ahmedabad Dist co-op Bank  -  Bank
# 60547, Bank of Baroda  -  Bank
# Cheque No. 866034 STATE BANK OF PATIALA NARIMAN POINT BRANCH,MUMBAI  -  Cheque
# 366114, Syndicate Bank  -  Bank
# 176279, HDFC  -  Others
# CHEQUE NO.  526575 HDFC BANK  -  Cheque
# CHEQUE NO. 338423 UNION BANK OF INDIA  -  Cheque
# CHEQUE NO. 336424 UNION BANK OF INDIA  -  Cheque
# 85371, Bank of Baroda  -  Bank
# 396091, Dena Bank  -  Bank
# 893477, Dena Bank  -  Bank
# Ch.No. 225289, Dt. 05.04.2014, Union Bank of India Mumbai-7, Dt. 05.04.2014  -  Cheque
# Ch.No. 221133, Dt. 05.04.2014, Union Bank of India Mumbai-7, Dt. 05.04.2014  -  Cheque
# 0000 34,  Bank of Baroda  -  Bank
# Cheque No. 204214 THE SARASWAT CO.OP.BANK MAHIM,MUMBAI  -  Cheque
# Cheque No. 204214 THE SARASWAT CO.OP.BANK MAHIM BRANCH,MUMBAI  -  Cheque
# 463754, Pragati Sahakari Bank Ltd  -  Bank
# 202767,  IDBI Bank , Boriwali(W) Branch  -  Bank
# RTGS Bank Of  Mahrastra  -  Bank
# 544 Kotak Mahindra Bank Nariman Point -21  -  Bank
# 906472 HDFC Bank churchgate Mumbai -20  -  Bank
# 39096, Axis Bank  -  Bank
# 74862, Navsarjan Co-Op Bank  -  Bank
# 258, Kotak Mahindra Bank  -  Bank
# 519113 Bank of Baroda  -  Bank
# 285685, Dena Bank  -  Bank
# 001121 Kotak Mahindra Bank Rajkot City  -  Bank
# 160, Bank of India  -  Bank
# Cheque No-   184472   Date  23.09.2008The Vijay Co-op Bank Ltd  -  Cheque
# 491333, Dena Bank  -  Bank
# 2526, Bank Of Baroda  -  Bank
# 87442, Central Bank of India  -  Bank
# 33503, Canara Bank  -  Bank
# 72683, Navsarjan Co-Op Bank  -  Bank
# 74221, Navsarjan Co-Op Bank  -  Bank
# Ch. No. 041443/dtd.07.10.2009Development Credit Bank Ltd. Hasanabad Branch Mumbai-400010  -  Cheque
# 90, Kotak Mahindra _x000D_
# _x000D_
# Bank  -  Bank
# 5172, Bank of Baroda  -  Bank
# Cheque No. 330697 CANARA BANK ANDHERI BRANCH,MUMBAI  -  Cheque
# 26077,  The Naroda Nagrik Co-op Bank  -  Bank
# 950900   Orental Bank Of Commerce  -  Bank
# 35082, The Bapunagar Mahila Co-op Bank  -  Bank
# 662, State Bank of India  -  Bank
# 100140,  ICICI Bank Versova Branch  -  Bank
# 427267, SBI Bank  -  Bank
# 1610, Bank of Baroda  -  Bank
# 84279, The Ahmedabad Dist Co-op Bank  -  Bank
# 000 336,  Bank of India, Mira RD. Branch  -  Bank
#   -  Others
# 54231, HDFC Bank  -  Bank
# 274, Kotak Mahindra Bank  -  Bank
# 30900, Peoples Co-op Bank  -  Bank
# 289414, Canara Bank  -  Bank
# 309025, _x000D_
# _x000D_
# Commercial Co-op Bank  -  Bank
# 389577,  Saraswat Bank, Opera House Branch  -  Bank
# 51038902, Union Bank of India  -  Bank
# 1167, Kotak Mahindra Bank  -  Bank
# 363808,  Union Bank, Videsi Vyapar Branch  -  Bank
# 41,  HDFC Bank  -  Bank
# 574407, IDBI  -  Others
# 576609, Indian Overseas Bank  -  Bank
# 530, Kotak Mahindra Bank  -  Bank
# 868, Bank of Baroda  -  Bank
# 656, Kotak Mahindra Bank  -  Bank
# 449478, SBPP C-Op Bank  -  Bank
# 0000 47, SBPP  -  Others
# 808026,  Punjab Nation Bank, Kandivali(W) Branch  -  Bank
# 808020,  Centeral Bank, Nariman Point Branch  -  Bank
# Ch. No-052311 Dated-13-04-2010Union Bank of India Gowalia Tank Branch Mumbai-400036  -  Cheque
# 44873, The _x000D_
# _x000D_
# Sutex Co-op Bank  -  Bank
# 596587, Syndicate Bank  -  Bank
# 000460 Kotak Mahindra  Bank Karnavati City  -  Bank
# 781677, Punjab National Bank Nagpur (Maharastra) Br.  -  Bank
# 186615, Oriental Bank of Commerce  -  Bank
# 000020, HDFC Bank Fort Mumbai Branch  -  Bank
# 000190, HDFC Bank Fort Mumbai Branch  -  Bank
# 000190 & 000385, HDFC Bank Fort Mumbai Branch  -  Bank
# 0000 81,  HDFC Bank Fort Mumbai  -  Bank
# 56985, Bank of India  -  Bank
# 64174, Union Bank  -  Bank
# 030511 IDBI Bank Rajkot City  -  Bank
# 91526   ICICI Bank  -  Bank
# Ch.No. 966787/Dt. 17.12.2012, Canara Bank _x000D_
# _x000D_
# Diplomatic Enclave Delhi-21  -  Cheque
# Ch.No. 904788/Dt. _x000D_
# _x000D_
# 17.01.2013, ICICI Bank E-17 South Extn Part II New Delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Ch No 772133 dtd 07-09-2011 State Bank of India, Parliament House, New Delhi  -  Cheque
# Cheque No 403632 Dtd. 2.02.2007Andhra Bank A.P Bhawan New Delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Cash  -  Cash
# Ch.No. 006429/Dt. 13.02.2013, State Bank Of _x000D_
# _x000D_
# India Parliament House New delhi  -  Cheque
# Ch.No. 626063/ Dt. 05.06.2012, State _x000D_
# _x000D_
# Bank Of India Parliament House New delhi  -  Cheque
# Cheque No 508522 Dtd. 24.11.206Satae Bank of India Parliament House  New Delhi  -  Cheque
# Ch.No. 810978/DT. 22.12.2012, State Bank Of _x000D_
# _x000D_
# India Parliament House New delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Ch.No. 617353/Dt. 17.01.2013, _x000D_
# _x000D_
# State Bank Of India Parliament House New delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Ch No 446178 dtd 22-03-2012 State Bank of India, Parliament House, New Delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# 490510, UCO Bank  -  Bank
# Through Bank Transfer  -  Bank
# Cheque No 981362 Dtd. 14.12.2006State Bank Of India Parilament House New Delhi  -  Cheque
# Ch.No.519426/dtd.03-03-2009 State Bank of India Parliament House New Delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Cheque  -  Cheque
# Through Bank Transfer  -  Bank
# S.I. -SBI-PH  -  Others
# Ch.No. 022060/Dt. 14.01.2013, Bank Of India Vikas Marg _x000D_
# _x000D_
# New Delhi  -  Cheque
# Cash  -  Cash
# Ch.No. 273064/ Dt. 30.05.2012, SBI Polo  -  Cheque
# By Cheque  -  Cheque
# Cash  -  Cash
# 405935, Bank of _x000D_
# _x000D_
# India  -  Bank
# 553736,  ICICI Bank  -  Bank
# 70431,  _x000D_
# _x000D_
# The Ahmedabad Co-op Bank  -  Bank
# Online Transfer  -  Others
# Through Bank Transfer  -  Bank
# Cash  -  Cash
# By Cash  -  Cash
# Cash  -  Cash
# Ch.No. 874252/Dt. 18.01.2013,State Bank Of _x000D_
# _x000D_
# India Parliament House New delhi  -  Cheque
# Cheque, Bank of India Parliament House New Delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Ch.No. 064266, Dt. 16.08.2012, SBI, New Tura  -  Cheque
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Cash  -  Cash
# Cash  -  Cash
# 765189, HDFC Bank  -  Bank
# Draft No. 169249  -  Others
# Draft No. 169895  -  Others
# 168133, Axis Bank  -  Bank
# Ch.No. 379981, SBBJ, Jaipur  -  Cheque
# Ch.No. 315548, SBBJ, Jaipur  -  Cheque
# 9461,  Saraswat Bank  -  Bank
# Through Bank Transfer  -  Bank
# 270411  -  Others
# 73456, State Bank of India  -  Bank
# 728919, HDFC  -  Others
# 619627, ICICI Bank  -  Bank
# 757510,  The Ahmedabad Dist.  -  Others
# Cash  -  Cash
# Cheque No.-  181008 The South Indian Bank Ltd. Channai  -  Cheque
# Cash  -  Cash
# By Cheque  -  Cheque
# Cheque No 007585 Date. 10.08.2006Centurion Bank Of Punjab Ltd, Bandra (West) Mumbai  -  Cheque
# 129035  -  Others
# 183938, Bank of Baroda  -  Bank
# 589444, Bank of Baroda  -  Bank
# 547271, Bank of Baroda  -  Bank
# 90683, BDCC  -  Others
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# 409921, _x000D_
# _x000D_
# State Bank of India  -  Bank
# 25531,  State Bank of India  -  Bank
# 677044, Akhand Anand Co-op Bank  -  Bank
# 504769, Bank of Baroda  -  Bank
# 427103, Standard Charterd  -  Others
# Through Bank Transfer  -  Bank
# Ch.No. 620497, Bank Of Patiala -10000257349  -  Cheque
# 000042, Bank of India  -  Bank
# 114844, Rajkot Nagarik Sahakari Bank  -  Bank
# 368494, Allahabad Bank  -  Bank
# Cash  -  Cash
# Cash  -  Cash
# DD.no. 518195/dDtd. 14.11.2005SBI Service Branch New Delhi  -  Others
# RC. No. 4024  -  Others
# 8,  HDFC Bank  -  Bank
# Cheque No-  175295   Date  13/05/2008Syndicate Bank  -  Cheque
# 538792, State Bank of India  -  Bank
# 538793, State Bank of India  -  Bank
# 538794, State Bank of India  -  Bank
# 538795, State Bank of India  -  Bank
# 538796, State Bank of India  -  Bank
# 221659, State Bank of India  -  Bank
# 616488  -  Others
# Ch No 092478 dtd 01-09-2011 State Bank of India, Parliament House, New Delhi  -  Cheque
# ...
# Ch No 915980 Dtd 28-02-2014, SBI Parliament House, New Delhi  -  Cheque
# Through Bank Transfer  -  Bank
# Cheque No- 299349,dt-17.08.2005Bank of india new delhi  -  Cheque
# Ch No 275398 Dtd 07-09-2013, SBI P.House, New Delhi  -  Cheque
# Cash  -  Cash
# Ch No 014457 Dtd 09-09-2013, IDBI, Gandhi Bagh, Nagpur  -  Cheque
# Ch No 022327 Dtd 09-09-2013, ICICI Bank, Nagpur  -  Cheque
# 228381  BANK OF INDIA, SAFDARJUNG NEW DELHI-110029  -  Bank
# CHEQUE NO. 254484 ICICI BANK PUNE  -  Cheque
# Ch. No-066091/Dated-01-12-2010  -  Cheque
# 902970,  Bank of Maharastra  -  Bank
# 273167, Sardar Bank  -  Bank
# 174153 IDBI Bank  -  Bank
# 59305 State Bank of Patiala  -  Bank
# Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# S.I. SBI-PH  -  Others
# 472, Bank of Baroda  -  Bank
# 318558 lndore Swayamsiddh Malila Co-Operative Bank  -  Bank
# 731827 Punjab National Bank  -  Bank
# 358531,  Dena Bank,Andheri (w) Br.  -  Bank
# Cheque No 133939 Date 25/11/11 HDFC Lakadkpoor  -  Cheque
# 487725PNB  -  Others
# 24197UBI DWARKA, NEW DELHI-110045  -  Others
# 067342, Bank of India  -  Bank
# 142137,  Saraswat Bank, Dadar(W) Branch  -  Bank
# 295832 SBI  -  Others
# Cheque No-.624344/624343   SBI  -  Cheque
# 142109 Bhopal co.op Central bank ltd.  -  Bank
# 218954    Sardar Vallabhai Sahakari Bank  -  Bank
# 649794ALLHABAD BANK  -  Bank
# 657832STATE BANK OF INDIA, DEHRADUN-248001  -  Bank
# Cheque No-  992395, Karnatka Bank Banglore  -  Cheque
# Cheque, Travelling Return  -  Cheque
# 4424KUMANCHAL NAGAR SAHKARI BANK LTD. DEHRADUN  -  Bank
# 560151, Punjab National Bank  -  Bank
# Through Bank Transfer  -  Bank
# 353248, Mehsana Urban _x000D_
# _x000D_
# Co-op Bank  -  Bank
# 256348, State Bank of India  -  Bank
# Cheque, Axis Bank Shri Ram Arcade, Rajpur Road Dehradun  -  Cheque
# 130068  AXIS BANK, ROHINI, NEW DELHI  -  Bank
# 119100  AXIS BANK, ROHINI, NEW DELHI  -  Bank
# 950231,  State Bank of India  -  Bank
# 789734, Dena Bank  -  Bank
# 505922 ,Bank Of Baroda  -  Bank
# 606333,  Punjab National Bank  -  Bank
# 813010Indian Overseas Bank  -  Bank
# Cheque No 285906 Date 3/1/12 HDFC SR Nagar  -  Cheque
# 288201  PNB, SHALIMAR BAGH, DELHI-16  -  Others
# Cheque, PNB Rani Pokhri Dehradun  -  Cheque
# Cheque No 314743   Oriental Bank Of Commerce 1/678, Kabool Nagar New Delhi  -  Cheque
# 564478ICICI BANK, SADAR BAZAR, NEW DELHI-110006  -  Bank
# 817744 HDFC Bank Ltd  -  Bank
# 804341,  ICICI Bank  -  Bank
# Cash  -  Cash
# 160631 ICICI Bank  -  Bank
# 981010 Bank of Maharashtra  -  Bank
# 333558Canara Bank  -  Bank
# 646420,  Canara Bank  -  Bank
# S.I. SBI-PH  -  Others
# 7436, ICICI Bank  -  Bank
# 58178 ,Bank Of India  -  Bank
# 391770 Axis Bank Hirandani Bussiness Park Mumbai  -  Bank
# 391771 Axis Bank Hirandani Bussiness Park Mumbai  -  Bank
# 391772Axis Bank Hirandani Bussiness Park Mumbai  -  Bank
# 422549 State Bank Of India  -  Bank
# 984097  -  Others
# 00 2427,  Allahabad Bank  -  Bank
# Cash  -  Cash
# cash  -  Cash
# S.I. SBI-PH & Cash  -  Cash
# Cash  -  Cash
# Cheque  -  Cheque
# 513667,  HDFC Bank  -  Bank
# 513668,  HDFC Bank  -  Bank
# 000561, The Mehsana Urban Co-op Bank  -  Bank
# 546, Bank of Baroda  -  Bank
# 22055,  Bank of Idian Vododara Banch  -  Bank
# 104510OBC, RAIPUR  -  Others
# 1948, Bank of Baroda  -  Bank
# 25660, Bank of India  -  Bank
# Cheque No-  112446,UTI  Bank Ltd Fort Mumbai  -  Cheque
# 83658PNB, NANGAL DEWAT, DELHI-110037  -  Others
# 266788,Allahabad Bank  -  Bank
# 165505, The Kalupur Commercial co-op _x000D_
# _x000D_
# Bank  -  Bank
# 00 8470,  Ratnakar Bank, Boriwali(W) Branch  -  Bank
# 830126 HDFC BANK LTD. USHA KIRAN COPLEX, S.D.  ROAD SECUNDERABAD  -  Bank
# 670119   HDFC BANK, BAREILY, NEW DELHI-243001  -  Bank
# cash  -  Cash
# Through Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# S.I. SBI-PH  -  Others
# Cheque State bank of india parliament street new delhi  -  Cheque
# 124158 Corporataion Bank Raipur Pandari  -  Bank
# 3,  HDFC Bank  -  Bank
# 4,  HDFC Bank  -  Bank
# 5,  HDFC Bank  -  Bank
# 6,  HDFC Bank  -  Bank
# 7,  HDFC Bank  -  Bank
# Cheque No-370064,UBI  -  Cheque
# Cheque No- 731098,dt-06.04.2004Union bank of india shalimar bagh new delhi  -  Cheque
# 316299, _x000D_
# _x000D_
# State Bank of India  -  Bank
# Cheque No. 314945HDFC BANK SANTACRUZ BRANCH,MUMBAI  -  Cheque
# 237587, ICICI Bank, Ghatkoper Branch  -  Bank
# 436, Kotak Mahindra Bank  -  Bank
# 545002, Bank of Baroda  -  Bank
# 596462  -  Others
# 272460, _x000D_
# _x000D_
# Sardar Vallabhbhai Bank  -  Bank
# 219158    Sardar Vallabhai Sahakari Bank  -  Bank
# 219157    Sardar Vallabhai Sahakari Bank  -  Bank
# Cash  -  Cash
# Bank Transfer  -  Bank
# Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# S.I. SBI-PH  -  Others
# Through Bank Transfer  -  Bank
# Cheque No-  36046   Date  07.02.2009Bank of India, Bhopal  -  Cheque
# Cheque No-  25093 Date 27.09.2008Bank of India  -  Cheque
# Cheque No-  10742   Bank of India, Bhopal  -  Cheque
# Cheque No-   25782  Date 22.11.2008Bank of India  -  Cheque
# 9065  BOI  -  Others
# 823942, State Bank of India  -  Bank
# 306764,  Bharat Bank, Vileparle Branch  -  Bank
# 270634, State Bank of Mysore  -  Bank
# 762148, _x000D_
# _x000D_
# Canara Bank  -  Bank
# 280946, Canara Bank  -  Bank
# 281077, Canara Bank  -  Bank
# 10074, Cental Bank of India  -  Bank
# 262436 Onental Bank Of Commerce  -  Bank
# 328961UCO BANK, SHIMLA, H.P.-171004  -  Bank
# Cash  -  Cash
# 353154, State Bank of India  -  Bank
# 783, HDFC Bank  -  Bank
#   -  Others
# 133572 Bank of Baroda  -  Bank
# 400181, State Bank _x000D_
# _x000D_
# of India  -  Bank
# Cash  -  Cash
# Ch. Mno-731644HDFC Bank Lajpat Nagar New Delhi  -  Cheque
# 222518,  State Bank of India  -  Bank
# 417695PNB, SHARSTRI NAGAR, DELHI-110052  -  Others
# 213107 Uco Bank  -  Bank
# Cheque, Bank of Maharashtra Pune  -  Cheque
# 817141,  State Bank of India, Nariman Point Branch  -  Bank
# 123351, Savodaya Co-op Bank  -  Bank
# 87132, Central Bank of India  -  Bank
# Cash  -  Cash
# 00 708,  HDFC Bank, Vasco  -  Bank
# 880361, HDFC Bank  -  Bank
# 29293 HDFC Bank Ltd  -  Bank
# 499543HDFC, PASCHIM VIHAR NEW DELHI- 110063  -  Others
# 1246877 Kangra Kendriya sahkari bank  -  Bank
# Ch.No. 257212, Andhra Bank Preet Vihar  -  Cheque
# Ch. No. 686257Andhra Bank Preet Vihar  -  Cheque
# Cheque No- 661522, Andhra Bank Preet Vihar  -  Cheque
# Ch.No. 146761, Andhara Bank _x000D_
# _x000D_
# Preet Vihar  -  Cheque
# 346999 Axis Bank  -  Bank
# Through Bank Transfer  -  Bank
# 217972 Axis Bank Ltd.  -  Bank
# Cheque No- 82220,dt-10.06.2004Indian oversease bank new delhi  -  Cheque
# 50392,  IDBI Bank  -  Bank
#   -  Others
# 960, HDFC Bank  -  Bank
# 62671, HDFC Bank  -  Bank
# cash  -  Cash
# 682663  -  Others
# chq no  526461 Bank of Maharstra  -  Bank
# 100186BOI  -  Others
# Cheque No. 751999 THE C.K.P.CO.OP.BANK LTD DADAR BRANCH,MUMBAI  -  Cheque
# Cheque No. 752008 THE C.K.P.CO.OP.BANK LTD DADAR BRANCH,MUMBAI  -  Cheque
# 17597,  Andhra Bank, Fort Mumbai Branch  -  Bank
# 69513, HDFC Bank, Tulsani Chambers, Nariman Point Branch  -  Bank
# 69516,  HDFC Bank, Tulsiani Branch, Nariman Point  -  Bank
# Cheque, State Bank of India Shilaj Road Branch  -  Cheque
# Through Bank Transfer  -  Bank
# Through Bank Transfer  -  Bank
# Cheque No.737799  -  Cheque
# 17764, ICICI Bank  -  Bank
# Cash  -  Cash
# Bank Transfer,  SBI-Parliamentry  -  Bank
# 455279SBI, BARKOT, UTTARKASHI-249141  -  Others
# Cash  -  Cash
# 528603 SBI  -  Others
# 176522    Sardar Vallabhai Sahakari Bank  -  Bank
# Cheque No.243052,Dated 18.03.2009  -  Cheque
# 481237, Punjab National Bank  -  Bank
# 51460ANDHRA BANK, DWARKA, NEW DELHI-110075  -  Bank
# 37676 HDFC BANK  -  Bank
# 283000   HDFC BANK  -  Bank
# Cheque No-716772, Bombai Mer. Co-Opretive, Darya Jung,  -  Cheque
# 140, Bank of Baroda  -  Bank
# 551370, Uco Bank  -  Bank
# 490975, The Co-op Bank of India  -  Bank
# 140598AXIS BANK, NAGPUR, MAHARASHTRA-440001  -  Bank
# 255368,  ICICI Bank, Vileparle Branch  -  Bank
# Cash  -  Cash
# Cash  -  Cash
# By RTGS/ Checques/Transfer  -  Others
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# 311905, Bank of Baroda  -  Bank
# 346342UNION BANK OF INDIA, RUDRAPUR-550515  -  Bank
# 311317, _x000D_
# _x000D_
# The Navanagar Co-op Bank  -  Bank
# Bank Transfer,  SBI-Parliamentry  -  Bank
# 373673SBI, SANSAD MARG, NEW DELHI-110001  -  Others
# 146222 J7K BANK  -  Bank
# 030201, Central Bank  -  Bank
# 0 54704,  Axis Bank Ltd  -  Bank
# 187395 SBI  -  Others
# 442455 Punjab National Bank  -  Bank
# DD. NO.- 975459/Dated- 16-04-2010Syndicate Bank Berasia Road Bhopal, MP  -  Bank
# RTGS  -  Others
# 114530 Axis Bank  -  Bank
# 887730, HDFC Bank  -  Bank
# 49916,  Union Bank of India  -  Bank
# 469100CORPORATION BANK  -  Bank
#   -  Others
# 065331, Sardar Vallabhbhai Sahakari Bank  -  Bank
# 305977,  New India Bank, Andheri (E ) Br.  -  Bank
# 672694PUNJAB NATIONAL BANK  -  Bank
#   -  Others
# 222496,  State Bank of India  -  Bank
#   -  Others
# 438430, ICICI Bank Bandra Branch  -  Bank
# 274993 State Bank Of Indore  -  Bank
# 424824 Axis Bank Ltd.  -  Bank
# 036243, Bank of India Campal  -  Bank
# 00 1345,  HDFC Bank, Mapusa  -  Bank
#   -  Others
# Cheque No- ICICI Bank Ltd.  -  Cheque
# 2348  -  Others
# Cheque No.-  26184 ICICI Bank Ltd. Panaji  -  Cheque
# 105102, Saraswat Bank Panaji Branch  -  Bank
# Cheque  -  Cheque
# 2073 Union Bank of India  -  Bank
# 295961  -  Others
# 396470  -  Others
# Cheque No. 182239THE UNITED WESTERN BANK LTD PRABHADEVI BRANCH,MUMBAI  -  Cheque
# Cheque No. 182241 THE UNITED WESTERN BANK LTD PRABHADEVI BRANCH,MUMBAI  -  Cheque
# Cheque No. 182242 THE UNITED WESTERN BANK LTD PRABHADEVI BRANCH,MUMBAI  -  Cheque
# 473359, Apni Sahakari Bank  -  Bank
# Cheque No-  516580   Date  19.11.2008Bank of India  -  Cheque
# 265998,  Corporation Bank, Boriwali(W) Branch  -  Bank
# 134  -  Others
# Cheque No-  437976    Date  7/5/2008Indian Bank  -  Cheque
# 130420 Indian park fort br.  -  Others
# 800030,  Janakalyan Sahkari Bank, Mulund (East) Branch  -  Bank
# Ch. No- 688575, Date-13-05-2010State Bank of India UP, Civil Secreatariate Vidhan Sabha Marg, Lucknow, UP  -  Cheque
# 154976,  Syndicate Bank  -  Bank
# 34692 HDFC Bank Ltd  -  Bank
# 16417, The Nasik Merchant co-op Bank  -  Bank
# 00 6605,  Kotak Mahindra  Bank, Nariman Point Branch  -  Bank
# 00 6604,  Kotak Mahindra  Bank, Nariman Point Branch  -  Bank
# 004007, Kotak _x000D_
# _x000D_
# Mahindra Bank  -  Bank
# 6850,  Kotak Mahindra Bank, Nariman Point Branch  -  Bank
# 6851,  Kotak Mahindra Bank, Nariman Point Branch  -  Bank
# 6852,  Kotak Mahindra Bank, Nariman Point Branch  -  Bank
# 2540HDFC, DEHRADUN, UTTARANCHAL-248001  -  Others
# 671448Bank of Mahrastra  -  Bank
# Cash  -  Cash
# 438326, Tamilnadu Bank  -  Bank
# 222526,  State Bank of India  -  Bank
# 804342, ICICI Bank  -  Bank
# 82800 Kalupur Com.Bank Karnavati City  -  Bank
# 001418, HDFC Bank Vasco  -  Bank
# 000678, HDFC Bank Vasco  -  Bank
# 122784 Axis Bank  -  Bank
# 489952,  Karnataka Bank  -  Bank
# 175445, HDFC  -  Others
# 289638, HDFC  -  Others
# Cheque No. 124872 HDFC BANK, FOT BRANCH, MUMBAI  -  Cheque
# 273826, State Bank of India  -  Bank
# 003701, Bank of India Campal-Panaji  -  Bank
# 004754, Bank of India Campal-Panaji  -  Bank
# Kotak Mahindra  -  Others
# ICICI Bank Ltd.  -  Bank
# 257573,  IDBI Bank  -  Bank
# Cheque  -  Cheque
# Through Bank Transfer  -  Bank
# 872221, HDFC Bank  -  Bank
# Cheque  -  Cheque
# 399505, ICICI Bank, Bandra West Branch  -  Bank
# 802018, Standard Chartered Bank, Bandra Kurla Complex, Bandra East Branch  -  Bank
# Ch. No- 180068/Dated-17-12-2010  -  Cheque
# Cheque No. 1581 UTI, BANK,UDAIPUR  -  Cheque
# Cheque No-  187502, HDFC Bank Fort Mumbai  -  Cheque
# 533944  The Bank of Rajasthan  -  Bank
# Ch No 961331, Dtd 05-09-2013,SBI, Parliament House, New Delhi  -  Cheque
# Cheque, State Bank of India Parliament House New Delhi  -  Cheque
# S.I. SBI-PH  -  Others
# Ceque No 378372 Date 8/8/11  -  Others
# 471373, PNB  -  Others
# 624665, Oriental Bank of Commerce  -  Bank
# 002360, Bank of Baroda  -  Bank
# 2133, Bank of Baroda  -  Bank
# 605101  UTI Bank  -  Bank
# 408000, Yes Bank  -  Bank
# 0 81689,  City Bank, N A Pune  -  Bank
# CHEQUE NO. 306 ICICI BANK  -  Cheque
# CHEQUE NO. 161958 UTI BANK  -  Cheque
# CHEQUE NO.  62741 UTI BANK  -  Cheque
# 34348, ICICI Bank  -  Bank
# 045896, Axis Bank  -  Bank
# 573722, Axis Bank  -  Bank
# CHEQUE NO. 550321 ICICI BANK. PUNE  -  Cheque
# M.P. Levy Adjustment Membership  -  Others
# M.P. Levy Adjustment, Membership Fee  -  Others
# D/D, Party Fund Our State Unit  -  Others
# 148033, Union Bank of India  -  Bank
# 171889, Karur Vysya Bank  -  Bank
# 0 39772,  NKGSB Bank, Vileparle (East) Branch  -  Bank
# Cheque No.483309,Dated 24.10.2005 Federal Bank Ltd.Banglore  -  Cheque
# Demand Draft No.409760,Dated 01.08.2005  -  Others
# Cash  -  Cash
# Dd.no. 070437 dt-16.04.2004Standard & chartered bank kolkata  -  Bank
# 551724,  The Varachha Co-op Bank  -  Bank
# Draft 199356  -  Others
# 316038  SBI  -  Others
# Demand Draft 199356 Ranchi  -  Others
# Cheque, SBI, Main Branch 4 Convent Road Dehradun  -  Cheque
# 330249, ICICI Bank  -  Bank
# 330274, ICICI Bank Ltd Nariman Point Br.  -  Bank
# Cheque, ICICI Bank Ltd Nariman Point Br. Mumbai  -  Cheque
# Ch No. 584394/ dtd. 23-04-2009  HDFC Bank Ltd. Udaipur Branch.  -  Cheque
# 450300,  Axis Bank Ltd  -  Bank
# DD.no. 112353,dt-13.04.2004Vijaya bank kolkata  -  Bank
# 514870, Bank of Baroda  -  Bank
# 24589 BOI  -  Others
# 000572, HDFC Bank  -  Bank
# 000 260,  HDFC Bank  -  Bank
# Cheque No.582562,Dated 13.12.2007, Federal Bank  -  Cheque
# Cheque No.500998,Dated 29.05.2006, Vijaya Bank  -  Cheque
# 789791, HDFC  -  Others
# 835468 Icici Bank , Faridabad  -  Bank
# 788882,  SBI, Balapur Road Hyderabad-79  -  Others
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# Cash  -  Cash
# Cheque State bank of india parliament street new delhi  -  Cheque
# 731387   ICICI Bank  -  Bank
# 599491, Punjab National Bank  -  Bank
# 40921, The Bhagyodaya Co.Bank  -  Bank
# Cash  -  Cash
# 279186, HDFC Bank  -  Bank
# 580658, Central Bank of India  -  Bank
# 57, Bank of Baroda  -  Bank
# 81, Karur Vysya Bank  -  Bank
# 361919, Tamiland Mercantile Bank Ltd  -  Bank
# 272159, Yes Bank  -  Bank
# 629729 PNB  -  Others
# 40, Bank of Baroda  -  Bank
# 355291, HDFC Bank  -  Bank
# Cheque No. 171599 HDFC BANK NANI DAMAN BRANCH, DAMAN  -  Cheque
# Cheque No-  0 00566   Date  28.05.2008Bank of India  -  Cheque
#   -  Others
# 101190  -  Others
# Cash  -  Cash
# 266314, Canara Bank  -  Bank
# 871994 Punjab National Bank  -  Bank
# Ch.No. 043621, PNB Geetanjali  -  Cheque
# 667715PUNJAB NATIONAL BANK  -  Bank
# 224486 HDFC Bank Ltd  -  Bank
# 965547,Axis Bank Pitampura  -  Bank
# 616291, Punjab National Bank  -  Bank
# 301801,  State Bank of India  -  Bank
# 545817, Satpuda Narmda Chetriya Gra.  -  Others
# Cheque No.845581 Central Bank of India  -  Cheque
# cash  -  Cash
# Cash.  -  Cash
# Bank Transfer,  SBI-Parliamentry  -  Bank
# 670504,  Dena Bank,Andheri (w) Br.  -  Bank
# 39885, HDFC Bank  -  Bank
# Cheque No-201902, Union Bank of India  -  Cheque
# 321121, Punjab National Bank  -  Bank
# Cheque No-  343736, Icici Bank Nariman Point Mumbai  -  Cheque
# Ch.No. 000070, Dt. Bank of Baroda, Dt. 02.06.2014, 4787, Dt. 05.06.2014  -  Cheque
# 401346  INDIAN OVERSEAS BANK  -  Bank
# 356449  ICICI BANK  -  Bank
# Cheque No. 490581 HDFC BANK ANDHERI BRANCH,MUMBAI  -  Cheque
# S.I. SBI-PH  -  Others
# 511542, The Ahmedabad Dsitricto.  -  Others
# 160864, HDFC Bank  -  Bank
# 18, Bank of India  -  Bank
# 56527, State Bank of India  -  Bank
# 601958, Dena Bank  -  Bank
# Cash  -  Cash
# Cash  -  Cash
# 58951, State Bank of India  -  Bank
# 826719, ICICI Bank  -  Bank
# Cheque No-173337, ICICI Bank  -  Cheque
# Cheque No-153805, Bank of Baroda  -  Cheque
# Cheque No-755371, Oriental Bank  -  Cheque
# RTGS No. 911020040934238, Dt. 16.10.2014  -  Others
# 15288, Bank of Baroda  -  Bank
# 520783,  Syndicate Bank, Matunga Branch  -  Bank
# 520784,  Syndicate Bank, Matunga Branch  -  Bank
# 000 187,  HDFC Bank  -  Bank
# 000 186,  HDFC Bank  -  Bank
# Cheque Canara bank otrem lane delhi  -  Cheque
# 0 55018,  Cosmos Bank, Vileparle (E ) Branch  -  Bank
# Cheque No- 036938,dt-03.01.2005Andhra bank andheri mumbai  -  Cheque
# 503499 Canara Bank Panaji  -  Bank
# Ch. No-029839, Dated-13-10-2010ICICI Bank Ltd. Vadodara Branch Vadodara  -  Cheque
# 032088, Bank of Baroda Gorwa  -  Bank
# 052750, ICICI Bank  -  Bank
# Cheque, HDFC Bank Ltd Navrangpura Br. Ahmedabad  -  Cheque
# 853, HDFC Bank  -  Bank
# 855, HDFC Bank  -  Bank
# 854, HDFC Bank  -  Bank
# 250506BANK OF BARODA  -  Bank
# 250507BANK OF BARODA  -  Bank
# 901983, Bank of Baroda  -  Bank
# Ch No- 170996, Date 31-03-2014, Bank Of Baroda Ahmadabad Branch  -  Cheque

# %% [markdown]
# #### 5. Calculate aggregates per party

# %% [markdown]
# 5.1 Calculate the Sum aggregation per party

# %%
df2 = df2.withColumn("Amount", df2["Amount"].cast(IntegerType()))
df2.groupBy("Party").sum("Amount").show()
# Out:
# +------+-----------+
# | Party|sum(Amount)|
# +------+-----------+
# |   INC| 4031487349|
# |   BJP| 9295525996|
# |   NCP|  647911419|
# |   CPI|   68123698|
# |CPI(M)|  150622128|
# +------+-----------+

# %%
#add column for party sum

INC = df2.groupBy("Party").sum("Amount").filter(df2.Party == 'INC').select("sum(Amount)").collect()
BJP = df2.groupBy("Party").sum("Amount").filter(df2.Party == 'BJP').select("sum(Amount)").collect()
NCP = df2.groupBy("Party").sum("Amount").filter(df2.Party == 'NCP').select("sum(Amount)").collect()
CPI = df2.groupBy("Party").sum("Amount").filter(df2.Party == 'CPI').select("sum(Amount)").collect()
CPI_M = df2.groupBy("Party").sum("Amount").filter(df2.Party == 'CPI(M)').select("sum(Amount)").collect()

partyList = ['INC', 'BJP', 'NCP', 'CPI', 'CPI(M)']
sumList = ['INC_SUM_LTD', 'BJP_SUM_LTD', 'NCP_SUM_LTD', 'CPI_SUM_LTD', 'CPI_M_SUM_LTD']
sumValue = [INC[0][0], BJP[0][0], NCP[0][0], CPI[0][0], CPI_M[0][0]]


for i in range(0, len(sumList)):
    # print(partyList[i], sumList[i], type(sumValue[i]), sumValue[i])
    df2 = df2.withColumn(sumList[i], lit(0))
    df2 = df2.withColumn(sumList[i], when(df2["Party"].contains(partyList[i]), sumValue[i]).otherwise(0))

# %% [markdown]
# 5.2 Calculate the Count aggregation per party

# %%
df2.groupBy("Party").count().show()
INC = df2.groupBy("Party").count().filter(df2.Party == 'INC').select("count").collect()
print(INC[0][0])
# Out:
# +------+-----+
# | Party|count|
# +------+-----+
# |   INC| 3785|
# |   BJP| 8782|
# |   NCP|  107|
# |   CPI|  384|
# |CPI(M)|  515|
# +------+-----+
#
# 3785

# %%
#add column for party COUNT
INC = df2.groupBy("Party").count().filter(df2.Party == 'INC').select("count").collect()
BJP = df2.groupBy("Party").count().filter(df2.Party == 'BJP').select("count").collect()
NCP = df2.groupBy("Party").count().filter(df2.Party == 'NCP').select("count").collect()
CPI = df2.groupBy("Party").count().filter(df2.Party == 'CPI').select("count").collect()
CPI_M = df2.groupBy("Party").count().filter(df2.Party == 'CPI(M)').select("count").collect()

partyList = ['INC', 'BJP', 'NCP', 'CPI', 'CPI(M)']
countList = ['INC_COUNT_LTD', 'BJP_COUNT_LTD', 'NCP_COUNT_LTD', 'CPI_COUNT_LTD', 'CPI_M_COUNT_LTD']
countValue = [INC[0][0], BJP[0][0], NCP[0][0], CPI[0][0], CPI_M[0][0]]


for i in range(0, len(countList)):
    # print(partyList[i], countList[i], type(countValue[i]), countValue[i])
    df2 = df2.withColumn(countList[i], lit(0))
    df2 = df2.withColumn(countList[i], when(df2["Party"].contains(partyList[i]), countValue[i]).otherwise(0))

# %% [markdown]
# 5.3 Calculate the Average aggregation per party

# %%
df2.groupBy("Party").avg('Amount').show()
INC = df2.groupBy("Party").avg('Amount').filter(df2.Party == 'INC').select("avg(Amount)").collect()
print(INC[0][0])
# Out:
# +------+------------------+
# | Party|       avg(Amount)|
# +------+------------------+
# |   INC|1065122.1529722589|
# |   BJP|1058474.8344340697|
# |   NCP| 6055246.906542056|
# |   CPI|177405.46354166666|
# |CPI(M)| 292470.1514563107|
# +------+------------------+
#
# 1065122.1529722589

# %%
#add column for party AVG
INC = df2.groupBy("Party").avg('Amount').filter(df2.Party == 'INC').select("avg(Amount)").collect()
BJP = df2.groupBy("Party").avg('Amount').filter(df2.Party == 'BJP').select("avg(Amount)").collect()
NCP = df2.groupBy("Party").avg('Amount').filter(df2.Party == 'NCP').select("avg(Amount)").collect()
CPI = df2.groupBy("Party").avg('Amount').filter(df2.Party == 'CPI').select("avg(Amount)").collect()
CPI_M = df2.groupBy("Party").avg('Amount').filter(df2.Party == 'CPI(M)').select("avg(Amount)").collect()

partyList = ['INC', 'BJP', 'NCP', 'CPI', 'CPI(M)']
avgList = ['INC_AVG_LTD', 'BJP_AVG_LTD', 'NCP_AVG_LTD', 'CPI_AVG_LTD', 'CPI_M_AVG_LTD']
avgValue = [INC[0][0], BJP[0][0], NCP[0][0], CPI[0][0], CPI_M[0][0]]


for i in range(0, len(avgList)):
    # print(partyList[i], avgList[i], type(avgValue[i]), avgValue[i])
    df2 = df2.withColumn(avgList[i], lit(0))
    df2 = df2.withColumn(avgList[i], when(df2["Party"].contains(partyList[i]), avgValue[i]).otherwise(0))

# %% [markdown]
# 5.4 Calculate the Max aggregation per party

# %%
df2.groupBy("Party").max('Amount').show()
INC = df2.groupBy("Party").max('Amount').filter(df2.Party == 'INC').select("max(Amount)").collect()
print(INC[0][0])
# Out:
# +------+-----------+
# | Party|max(Amount)|
# +------+-----------+
# |   INC|  500000000|
# |   BJP|  500000000|
# |   NCP|   50000000|
# |   CPI|    3000000|
# |CPI(M)|   10000000|
# +------+-----------+
#
# 500000000

# %%
#add column for party MAX
INC = df2.groupBy("Party").max('Amount').filter(df2.Party == 'INC').select("max(Amount)").collect()
BJP = df2.groupBy("Party").max('Amount').filter(df2.Party == 'BJP').select("max(Amount)").collect()
NCP = df2.groupBy("Party").max('Amount').filter(df2.Party == 'NCP').select("max(Amount)").collect()
CPI = df2.groupBy("Party").max('Amount').filter(df2.Party == 'CPI').select("max(Amount)").collect()
CPI_M = df2.groupBy("Party").max('Amount').filter(df2.Party == 'CPI(M)').select("max(Amount)").collect()

partyList = ['INC', 'BJP', 'NCP', 'CPI', 'CPI(M)']
maxList = ['INC_MAX_LTD', 'BJP_MAX_LTD', 'NCP_MAX_LTD', 'CPI_MAX_LTD', 'CPI_M_MAX_LTD']
maxValue = [INC[0][0], BJP[0][0], NCP[0][0], CPI[0][0], CPI_M[0][0]]


for i in range(0, len(maxList)):
    # print(partyList[i], maxList[i], type(maxValue[i]), maxValue[i])
    df2 = df2.withColumn(maxList[i], lit(0))
    df2 = df2.withColumn(maxList[i], when(df2["Party"].contains(partyList[i]), maxValue[i]).otherwise(0))

# %% [markdown]
# 6. Calculate top donor per party

# %%
# Top donor
INC_amt = df2.groupBy("Party").max('Amount').filter(df2.Party == 'INC').select("max(Amount)").collect()
res = df2.filter(df2['Amount'] == INC_amt[0][0]).select('Name').collect()
print(INC_amt[0][0], res[0][0])

BJP_amt = df2.groupBy("Party").max('Amount').filter(df2.Party == 'BJP').select("max(Amount)").collect()
res = df2.filter(df2['Amount'] == BJP_amt[0][0]).select('Name').collect()
print(BJP_amt[0][0], res[0][0])

NCP_amt = df2.groupBy("Party").max('Amount').filter(df2.Party == 'NCP').select("max(Amount)").collect()
res = df2.filter(df2['Amount'] == NCP_amt[0][0]).select('Name').collect()
print(NCP_amt[0][0], res[0][0])

CPI_amt = df2.groupBy("Party").max('Amount').filter(df2.Party == 'CPI').select("max(Amount)").collect()
res = df2.filter(df2['Amount'] == CPI_amt[0][0]).select('Name').collect()
print(CPI_amt[0][0], res[0][0])

CPI_M_amt = df2.groupBy("Party").max('Amount').filter(df2.Party == 'CPI(M)').select("max(Amount)").collect()
res = df2.filter(df2['Amount'] == CPI_M_amt[0][0]).select('Name').collect()
print(CPI_M_amt[0][0], res[0][0])
# Out:
# 500000000 General Electoral Trust
# 500000000 General Electoral Trust
# 50000000 A.V.Patil Foundation
# 3000000 Aziz Pasha
# 10000000 V K Ramachandran

# %%
partyList = ['INC', 'BJP', 'NCP', 'CPI', 'CPI(M)']
donorList = ['INC_TOP_DONOR', 'BJP_TOP_DONOR', 'NCP_TOP_DONOR', 'CPI_TOP_DONOR', 'CPI_M_TOP_DONOR']
donorValue = [INC_amt[0][0], BJP_amt[0][0], NCP_amt[0][0], CPI_amt[0][0], CPI_M_amt[0][0]]


for i in range(0, len(donorList)):
    df2 = df2.withColumn(donorList[i], lit(0))
    df2 = df2.withColumn(donorList[i], when(df2["Party"].contains(partyList[i]), donorValue[i]).otherwise(0))

# %% [markdown]
# 7. Calculate sum of donations per financial year per party and the column should be named as 2011-12_BJP_SUM

# %%
df2.groupBy('fin_year').sum('Amount').show(100)
# Out:
# +--------+-----------+
# |fin_year|sum(Amount)|
# +--------+-----------+
# | 2004-05|  661603287|
# | 2006-07|  153178304|
# | 2010-11|  253982700|
# | 2008-09|  647906691|
# | 2007-08|  350074020|
# | 2012-13|  991430132|
# | 2009-10| 1706671272|
# | 2014-15| 6223898440|
# | 2005-06|   99907293|
# | 2003-04|  146162222|
# | 2011-12|  480926109|
# | 2013-14| 2477930120|
# +--------+-----------+

# %%
# Per financial year
from pyspark.sql.functions import desc

df2.groupBy('Party', 'fin_year').sum('Amount').sort(col("Party").asc()).show(100)

result = df2.groupBy('Party', 'fin_year').sum('Amount').sort(col("Party").asc()).collect()
# Out:
# +------+--------+-----------+
# | Party|fin_year|sum(Amount)|
# +------+--------+-----------+
# |   BJP| 2010-11|  146253279|
# |   BJP| 2014-15| 4373506898|
# |   BJP| 2003-04|  116881973|
# |   BJP| 2011-12|  334194113|
# |   BJP| 2007-08|  249623653|
# |   BJP| 2012-13|  831924462|
# |   BJP| 2008-09|  306057231|
# |   BJP| 2004-05|  339521289|
# |   BJP| 2006-07|   29550672|
# |   BJP| 2009-10|  823220133|
# |   BJP| 2005-06|   36156111|
# |   BJP| 2013-14| 1708636182|
# |   CPI| 2011-12|    5982675|
# |   CPI| 2005-06|    3988690|
# |   CPI| 2003-04|     779148|
# |   CPI| 2008-09|    2585000|
# |   CPI| 2009-10|    8667852|
# |   CPI| 2004-05|     630000|
# |   CPI| 2014-15|   13346675|
# |   CPI| 2006-07|    1229400|
# |   CPI| 2010-11|   10811465|
# |   CPI| 2013-14|   12281544|
# |   CPI| 2012-13|    3695449|
# |   CPI| 2007-08|    4125800|
# |CPI(M)| 2007-08|    7226116|
# |CPI(M)| 2011-12|   23838657|
# |CPI(M)| 2008-09|    4155000|
# |CPI(M)| 2014-15|   34197498|
# |CPI(M)| 2010-11|   15357072|
# |CPI(M)| 2003-04|     200000|
# |CPI(M)| 2012-13|   38139996|
# |CPI(M)| 2009-10|    3962049|
# |CPI(M)| 2006-07|    1124719|
# |CPI(M)| 2013-14|   20974666|
# |CPI(M)| 2004-05|     896355|
# |CPI(M)| 2005-06|     550000|
# |   INC| 2014-15| 1414610950|
# |   INC| 2006-07|  121273513|
# |   INC| 2004-05|  320555643|
# |   INC| 2012-13|  117166225|
# |   INC| 2005-06|   59212492|
# |   INC| 2013-14|  595837728|
# |   INC| 2003-04|   28301101|
# |   INC| 2010-11|   80205884|
# |   INC| 2007-08|   78873451|
# |   INC| 2009-10|  840521238|
# |   INC| 2011-12|   95910664|
# |   INC| 2008-09|  279018460|
# |   NCP| 2012-13|     504000|
# |   NCP| 2013-14|  140200000|
# |   NCP| 2014-15|  388236419|
# |   NCP| 2011-12|   21000000|
# |   NCP| 2009-10|   30300000|
# |   NCP| 2010-11|    1355000|
# |   NCP| 2007-08|   10225000|
# |   NCP| 2008-09|   56091000|
# +------+--------+-----------+

# %%
financial_yr_data = df2.groupBy("Party","fin_year").sum("Amount").sort("fin_year")
financial_yr_data.show()
# Out:
# +------+--------+-----------+
# | Party|fin_year|sum(Amount)|
# +------+--------+-----------+
# |   INC| 2003-04|   28301101|
# |CPI(M)| 2003-04|     200000|
# |   BJP| 2003-04|  116881973|
# |   CPI| 2003-04|     779148|
# |   INC| 2004-05|  320555643|
# |CPI(M)| 2004-05|     896355|
# |   CPI| 2004-05|     630000|
# |   BJP| 2004-05|  339521289|
# |   CPI| 2005-06|    3988690|
# |   BJP| 2005-06|   36156111|
# |CPI(M)| 2005-06|     550000|
# |   INC| 2005-06|   59212492|
# |CPI(M)| 2006-07|    1124719|
# |   BJP| 2006-07|   29550672|
# |   INC| 2006-07|  121273513|
# |   CPI| 2006-07|    1229400|
# |   CPI| 2007-08|    4125800|
# |CPI(M)| 2007-08|    7226116|
# |   BJP| 2007-08|  249623653|
# |   NCP| 2007-08|   10225000|
# +------+--------+-----------+
# only showing top 20 rows

# %%
for row in financial_yr_data.collect():
    name = row[1] + "_" + row[0] + "_" + "SUM"
    df2 = df2.withColumn(name,lit('-'))
    df2 = df2.withColumn(name, when(col("Party") == row[0], row[2]).otherwise('-'))

# df2.show()

# %%
# check column list
df2.columns
# Out:
# ['Address',
#  'Amount',
#  'mode_of_payment',
#  'fin_year',
#  'Name',
#  'pan_given',
#  'Party',
#  'Type',
#  'field10',
#  'field11',
#  'field12',
#  'field13',
#  'field14',
#  'field9',
#  'payment_segregated',
#  'INC_SUM_LTD',
#  'BJP_SUM_LTD',
#  'NCP_SUM_LTD',
#  'CPI_SUM_LTD',
#  'CPI_M_SUM_LTD',
#  'INC_COUNT_LTD',
#  'BJP_COUNT_LTD',
#  'NCP_COUNT_LTD',
#  'CPI_COUNT_LTD',
#  'CPI_M_COUNT_LTD',
#  'INC_AVG_LTD',
#  'BJP_AVG_LTD',
#  'NCP_AVG_LTD',
#  'CPI_AVG_LTD',
#  'CPI_M_AVG_LTD',
#  'INC_MAX_LTD',
#  'BJP_MAX_LTD',
#  'NCP_MAX_LTD',
#  'CPI_MAX_LTD',
#  'CPI_M_MAX_LTD',
#  'INC_TOP_DONOR',
#  'BJP_TOP_DONOR',
#  'NCP_TOP_DONOR',
#  'CPI_TOP_DONOR',
#  'CPI_M_TOP_DONOR',
#  '2003-04_BJP_SUM',
#  '2003-04_CPI_SUM',
#  '2003-04_INC_SUM',
#  '2003-04_CPI(M)_SUM',
#  '2004-05_INC_SUM',
#  '2004-05_CPI(M)_SUM',
#  '2004-05_CPI_SUM',
#  '2004-05_BJP_SUM',
#  '2005-06_CPI(M)_SUM',
#  '2005-06_BJP_SUM',
#  '2005-06_INC_SUM',
#  '2005-06_CPI_SUM',
#  '2006-07_INC_SUM',
#  '2006-07_CPI(M)_SUM',
#  '2006-07_BJP_SUM',
#  '2006-07_CPI_SUM',
#  '2007-08_CPI_SUM',
#  '2007-08_BJP_SUM',
#  '2007-08_NCP_SUM',
#  '2007-08_CPI(M)_SUM',
#  '2007-08_INC_SUM',
#  '2008-09_BJP_SUM',
#  '2008-09_CPI(M)_SUM',
#  '2008-09_CPI_SUM',
#  '2008-09_NCP_SUM',
#  '2008-09_INC_SUM',
#  '2009-10_BJP_SUM',
#  '2009-10_CPI(M)_SUM',
#  '2009-10_NCP_SUM',
#  '2009-10_CPI_SUM',
#  '2009-10_INC_SUM',
#  '2010-11_BJP_SUM',
#  '2010-11_NCP_SUM',
#  '2010-11_INC_SUM',
#  '2010-11_CPI_SUM',
#  '2010-11_CPI(M)_SUM',
#  '2011-12_CPI(M)_SUM',
#  '2011-12_BJP_SUM',
#  '2011-12_CPI_SUM',
#  '2011-12_INC_SUM',
#  '2011-12_NCP_SUM',
#  '2012-13_CPI_SUM',
#  '2012-13_NCP_SUM',
#  '2012-13_INC_SUM',
#  '2012-13_CPI(M)_SUM',
#  '2012-13_BJP_SUM',
#  '2013-14_INC_SUM',
#  '2013-14_NCP_SUM',
#  '2013-14_BJP_SUM',
#  '2013-14_CPI(M)_SUM',
#  '2013-14_CPI_SUM',
#  '2014-15_INC_SUM',
#  '2014-15_NCP_SUM',
#  '2014-15_BJP_SUM',
#  '2014-15_CPI(M)_SUM',
#  '2014-15_CPI_SUM']

# %% [markdown]
# 8. Calculate number of donation till date per mode_of_payment

# %%
payment_modes_list = df2.groupBy("payment_segregated").count()

payment_modes_list.show()
# Out:
# +------------------+-----+
# |payment_segregated|count|
# +------------------+-----+
# |              Bank| 7251|
# |            Cheque| 2918|
# |              Cash|  918|
# |            Others| 2486|
# +------------------+-----+

# %%
for row in payment_modes_list.collect():
    name = row[0] + "_COUNT_LTD"
    df2 = df2.withColumn(name,lit('-'))
    df2 = df2.withColumn(name, when(col("payment_segregated") == row[0], row[1]).otherwise('-'))

# %%
df2.select("payment_segregated","BANK_COUNT_LTD","CHEQUE_COUNT_LTD","CASH_COUNT_LTD","OTHERS_COUNT_LTD").show()
# Out:
# +------------------+--------------+----------------+--------------+----------------+
# |payment_segregated|BANK_COUNT_LTD|CHEQUE_COUNT_LTD|CASH_COUNT_LTD|OTHERS_COUNT_LTD|
# +------------------+--------------+----------------+--------------+----------------+
# |              Cash|             -|               -|           918|               -|
# |              Bank|          7251|               -|             -|               -|
# |            Cheque|             -|            2918|             -|               -|
# |              Bank|          7251|               -|             -|               -|
# |              Bank|          7251|               -|             -|               -|
# |            Others|             -|               -|             -|            2486|
# |            Others|             -|               -|             -|            2486|
# |              Bank|          7251|               -|             -|               -|
# |            Others|             -|               -|             -|            2486|
# |              Bank|          7251|               -|             -|               -|
# |              Bank|          7251|               -|             -|               -|
# |            Others|             -|               -|             -|            2486|
# |            Cheque|             -|            2918|             -|               -|
# |            Cheque|             -|            2918|             -|               -|
# |            Cheque|             -|            2918|             -|               -|
# |              Bank|          7251|               -|             -|               -|
# |              Bank|          7251|               -|             -|               -|
# |              Bank|          7251|               -|             -|               -|
# |            Others|             -|               -|             -|            2486|
# |            Cheque|             -|            2918|             -|               -|
# +------------------+--------------+----------------+--------------+----------------+
# only showing top 20 rows

# %% [markdown]
# 9. Write the final data into parquet

# %%
df2.write.parquet("/content/drive/MyDrive/Colab Notebooks/donation-data.parquet")

# %%
drive.flush_and_unmount()
